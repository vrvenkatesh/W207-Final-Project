# %% [markdown]
# # Logistic Regression Baseline

# %% [markdown]
# This model serves as the baseline model for the binary classification series of models.
#
# The sections include:
# -Cleaning and preprocessing data <br>
# -Creating Metacritic Binary Variable <br>
# -Logistic Regression Model + Experiments<br>
# -Evaluate Model <br>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# data preprocessing
from sklearn import preprocessing

# exploratory analysis
import matplotlib.pyplot as plt
import mlxtend
from mlxtend.plotting import scatterplotmatrix
from mlxtend.plotting import heatmap
import seaborn as sns
sns.set(style="darkgrid")  # default style
from IPython.display import Image

# model fit
import statsmodels.api as sm
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.optimizers import Adam
from keras import metrics
tf.get_logger().setLevel('INFO')

# ignore warnings (libraries are rapidly changing)
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-04-13 10:36:46.909971: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def confusion_matrix_plot(conf_matrix):
    """ Confusion matrix matplotlib plot
    # param conf_matrix: nested list of TP, TN, FP, FN
    # return: None
    """
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            ax.text(x=j, y=i, s=conf_matrix[i, j], va='center', ha='center')

    plt.xlabel('Predicted label')
    plt.ylabel('True label')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Cleaning and Preprocessing Data

# %%
df_raw = pd.read_csv('games-features.csv')

# %%
df_raw.head()
# Out:
#    QueryID  ResponseID                  QueryName               ResponseName  \
# 0       10          10             Counter-Strike             Counter-Strike
# 1       20          20      Team Fortress Classic      Team Fortress Classic
# 2       30          30              Day of Defeat              Day of Defeat
# 3       40          40         Deathmatch Classic         Deathmatch Classic
# 4       50          50  Half-Life: Opposing Force  Half-Life: Opposing Force
#
#   ReleaseDate  RequiredAge  DemoCount  DeveloperCount  DLCCount  Metacritic  \
# 0  Nov 1 2000            0          0               1         0          88
# 1  Apr 1 1999            0          0               1         0           0
# 2  May 1 2003            0          0               1         0          79
# 3  Jun 1 2001            0          0               1         0           0
# 4  Nov 1 1999            0          0               1         0           0
#
#    ...  LegalNotice  Reviews  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#                                   SupportedLanguages  \
# 0  English French German Italian Spanish Simplifi...
# 1              English French German Italian Spanish
# 2              English French German Italian Spanish
# 3              English French German Italian Spanish
# 4                       English French German Korean
#
#                        Website  \
# 0                         None
# 1                         None
# 2  http://www.dayofdefeat.com/
# 3                         None
# 4                         None
#
#                                        PCMinReqsText  PCRecReqsText  \
# 0  Minimum: 500 mhz processor 96mb ram 16mb video...
# 1  Minimum: 500 mhz processor 96mb ram 16mb video...
# 2  Minimum: 500 mhz processor 96mb ram 16mb video...
# 3  Minimum: 500 mhz processor 96mb ram 16mb video...
# 4  Minimum: 500 mhz processor 96mb ram 16mb video...
#
#                                     LinuxMinReqsText  LinuxRecReqsText  \
# 0  Minimum: Linux Ubuntu 12.04 Dual-core from Int...
# 1  Minimum: Linux Ubuntu 12.04 Dual-core from Int...
# 2  Minimum: Linux Ubuntu 12.04 Dual-core from Int...
# 3  Minimum: Linux Ubuntu 12.04 Dual-core from Int...
# 4  Minimum: Linux Ubuntu 12.04 Dual-core from Int...
#
#                                       MacMinReqsText  MacRecReqsText
# 0  Minimum: OS X  Snow Leopard 10.6.3 1GB RAM 4GB...
# 1  Minimum: OS X  Snow Leopard 10.6.3 1GB RAM 4GB...
# 2  Minimum: OS X  Snow Leopard 10.6.3 1GB RAM 4GB...
# 3  Minimum: OS X  Snow Leopard 10.6.3 1GB RAM 4GB...
# 4  Minimum: OS X  Snow Leopard 10.6.3 1GB RAM 4GB...
#
# [5 rows x 78 columns]

# %% [markdown]
# ### Selecting rows and columns used for analysis

# %%
df_raw.columns
# Out:
# Index(['QueryID', 'ResponseID', 'QueryName', 'ResponseName', 'ReleaseDate',
#        'RequiredAge', 'DemoCount', 'DeveloperCount', 'DLCCount', 'Metacritic',
#        'MovieCount', 'PackageCount', 'RecommendationCount', 'PublisherCount',
#        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
#        'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
#        'AchievementCount', 'AchievementHighlightedCount', 'ControllerSupport',
#        'IsFree', 'FreeVerAvail', 'PurchaseAvail', 'SubscriptionAvail',
#        'PlatformWindows', 'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin',
#        'PCReqsHaveRec', 'LinuxReqsHaveMin', 'LinuxReqsHaveRec',
#        'MacReqsHaveMin', 'MacReqsHaveRec', 'CategorySinglePlayer',
#        'CategoryMultiplayer', 'CategoryCoop', 'CategoryMMO',
#        'CategoryInAppPurchase', 'CategoryIncludeSrcSDK',
#        'CategoryIncludeLevelEditor', 'CategoryVRSupport', 'GenreIsNonGame',
#        'GenreIsIndie', 'GenreIsAction', 'GenreIsAdventure', 'GenreIsCasual',
#        'GenreIsStrategy', 'GenreIsRPG', 'GenreIsSimulation',
#        'GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'GenreIsSports',
#        'GenreIsRacing', 'GenreIsMassivelyMultiplayer', 'PriceCurrency',
#        'PriceInitial', 'PriceFinal', 'SupportEmail', 'SupportURL', 'AboutText',
#        'Background', 'ShortDescrip', 'DetailedDescrip', 'DRMNotice',
#        'ExtUserAcctNotice', 'HeaderImage', 'LegalNotice', 'Reviews',
#        'SupportedLanguages', 'Website', 'PCMinReqsText', 'PCRecReqsText',
#        'LinuxMinReqsText', 'LinuxRecReqsText', 'MacMinReqsText',
#        'MacRecReqsText'],
#       dtype='object')

# %%
df_all = df_raw[['QueryName', 'Metacritic',
         #Genre variables
        'GenreIsNonGame', 'GenreIsIndie', 'GenreIsAction', 'GenreIsAdventure', 
         'GenreIsCasual','GenreIsStrategy', 'GenreIsRPG', 'GenreIsSimulation',
       'GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'GenreIsSports', 'GenreIsRacing',
         #Category variables
        'CategorySinglePlayer','CategoryMultiplayer', 'CategoryCoop', 'CategoryMMO',
       'CategoryInAppPurchase', 'CategoryIncludeSrcSDK',
       'CategoryIncludeLevelEditor', 'CategoryVRSupport',
         #Platform variables
        'PlatformWindows', 'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin',
       'PCReqsHaveRec', 'LinuxReqsHaveMin', 'LinuxReqsHaveRec',
       'MacReqsHaveMin', 'MacReqsHaveRec',
         #Additional Info
        'RequiredAge', 'DemoCount', 'DeveloperCount', 'DLCCount',
        'MovieCount', 'PackageCount', 'RecommendationCount', 
        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance','SteamSpyPlayersEstimate', 
         'SteamSpyPlayersVariance','AchievementCount', 'ControllerSupport', 'FreeVerAvail', 
         'PurchaseAvail', 'SubscriptionAvail', 'PriceFinal',
         #Variables that need transformation
         'ReleaseDate', 'SupportedLanguages', 
         #Text variables
         'Reviews','DetailedDescrip','AboutText']]

# %%
df = df_all[df_all['Metacritic']>0]

# %% [markdown]
# ### Dropping Duplicates

# %%
df = df.drop_duplicates()

# %%
df_vc = pd.DataFrame(df['QueryName'].value_counts())
df_vc[df_vc['QueryName']>1]
# Out:
#                                                QueryName
# Sid Meier's Civilization IV: Colonization              2
# Monday Night Combat                                    2
# Fallout: New Vegas                                     2
# Darksiders                                             2
# Alpha Protocol                                         2
# Sid Meier's Civilization V                             2
# Sid Meier's Civilization IV: Beyond the Sword          2
# Sid Meier's Civilization IV: Warlords                  2
# Arma 2                                                 2
# Sid Meier's Civilization IV                            2

# %%
#drop Sid Meier's Civilization IV: Colonization dup 
df=df.drop(965)
#drop Fallout: New Vegas dup
df=df.drop(952)
#drop Sid Meier's Civilization V dup
df=df.drop(1205)
#drop Darksiders dup
df=df.drop(1210)
#drop Sid Meier's Civilization IV dup
df=df.drop(962)
#Drop Monday night combat dup
df=df.drop(1278)
#Drop Sid Meier's Civilization IV: Beyond the Sword dup
df=df.drop(964)
#Drop Sid Meier's Civilization IV: Warlords dup
df=df.drop(963)
#Drop Arma 2 dup
df=df.drop(782)
#Drop Alpha Protocol dup
df=df.drop(961)

# %% [markdown]
# ### Cleaning Languages

# %%
import re
pd.set_option('display.max_rows', None)
languages = df['SupportedLanguages'].tolist()

#Split to check all languages
split_lst = []
for language in languages:
    split_lang = re.split('\* |\*|\s|\*\*', language)
    for lang in split_lang:
        split_lst.append(lang)

split_series = pd.Series(split_lst)
split_df = pd.DataFrame(split_series.value_counts())
#split_df[split_df[0]>0]
#lang_list= split_df.index.values.tolist()
#print(lang_list)

# %%
#Create list of all possible languages
language_list=['English', 'German', 'French', 'Spanish',  'Italian', 'Russian', 'Polish', 
               'Japanese', 'Portuguese-Brazil', 'Czech', 'Korean', 'Simplified Chinese', 
               'Dutch', 'Traditional Chinese', 'Portuguese', 'Hungarian', 'Turkish', 'Swedish', 
               'Danish', 'Norwegian', 'Finnish', 'Ukrainian', 'Romanian', 'Thai', 'Greek', 
               'Bulgarian', 'Arabic',  'Slovakian']

# %%
#Create boolean columns for each language
for language in language_list:
    df[language]=df['SupportedLanguages'].str.contains(language)

# %%
#create boolean column for audio support (will delete later, using this as reference to check regex)
df.loc[df['SupportedLanguages'].str.contains("languages with full audio support")==True, 'audio_support?'] = 1
df.loc[df['SupportedLanguages'].str.contains("languages with full audio support")==False, 'audio_support?'] = 0

# %%
#Create transformed language columns without "languages with full audio support" statement
df['transformed']= df['SupportedLanguages'].str.extract("(.+?)\*languages with full audio support")

# %%
#Count * in transformed column to count number of languages with audio support
df['num_lang_audio_support']=df['transformed'].str.count('\*')
df['num_lang_audio_support'] = df['num_lang_audio_support'].fillna(0)

# %%
#Convert bool to numeric and sum
df[['English', 'German', 'French', 'Spanish',  'Italian', 'Russian', 'Polish', 
               'Japanese', 'Portuguese-Brazil', 'Czech', 'Korean', 'Simplified Chinese', 
               'Dutch', 'Traditional Chinese', 'Portuguese', 'Hungarian', 'Turkish', 'Swedish', 
               'Danish', 'Norwegian', 'Finnish', 'Ukrainian', 'Romanian', 'Thai', 'Greek', 
               'Bulgarian', 'Arabic',  'Slovakian']] = df[['English', 'German', 'French', 'Spanish',  'Italian', 'Russian', 'Polish', 
               'Japanese', 'Portuguese-Brazil', 'Czech', 'Korean', 'Simplified Chinese', 
               'Dutch', 'Traditional Chinese', 'Portuguese', 'Hungarian', 'Turkish', 'Swedish', 
               'Danish', 'Norwegian', 'Finnish', 'Ukrainian', 'Romanian', 'Thai', 'Greek', 
               'Bulgarian', 'Arabic',  'Slovakian']].replace({True: 1, False: 0})

df['num_languages']=df[['English', 'German', 'French', 'Spanish',  'Italian', 'Russian', 'Polish', 
               'Japanese', 'Portuguese-Brazil', 'Czech', 'Korean', 'Simplified Chinese', 
               'Dutch', 'Traditional Chinese', 'Portuguese', 'Hungarian', 'Turkish', 'Swedish', 
               'Danish', 'Norwegian', 'Finnish', 'Ukrainian', 'Romanian', 'Thai', 'Greek', 
               'Bulgarian', 'Arabic',  'Slovakian']].sum(axis=1)

# %%
#Drop columns used in transformations
df=df.drop("transformed", axis=1)
df=df.drop("audio_support?", axis=1)

# %% [markdown]
# ### Cleaning Dates

# %%
#Check for dates with inaccurate format
df['ReleaseDate'][df['ReleaseDate'].str.fullmatch('[a-zA-Z]{3}\s\d*?\s\d{4}')==False]
# Out:
# 305                Feb 2011
# 529
# 572
# 668                Jun 2009
# 687                Jul 2010
# 904                Sep 2009
# 1008
# 1180               Mar 2010
# 1199
# 1228               Apr 2010
# 1253               Jul 2010
# 1268               Oct 2010
# 1269               Oct 2010
# 1578
# 1856
# 1922
# 1993
# 2171
# 2183
# 2201
# 2214
# 2317               Aug 2013
# 3805               Nov 2014
# 4103               May 2015
# 4943               Jun 2015
# 12068    December 20th 2016
# Name: ReleaseDate, dtype: object

# %%
#Convert these dates to accurate format, replace blanks with NAs
df['ReleaseDate']= df['ReleaseDate'].replace({'Oct 2010': 'Oct 1 2010', 'Jul 2010':'Jul 1 2010', 'Aug 2013': 'Aug 2013',
                          'Jun 2015': 'Jun 1 2015', 'December 20th 2016': 'Dec 20 2016',
                          'May 2015': 'May 1 2015', 'Nov 2014': 'Nov 1 2014', 'Sep 2009':'Sep 1 2009',
                          'Jun 2009': 'Jun 1 2009', 'Feb 2011':'Feb 1 2011', 'Mar 2010':'Mar 1 2010',
                          'Apr 2010': 'Apr 1 2010', 'Aug 2013': 'Aug 1 2013'})
df['ReleaseDate'] = df['ReleaseDate'].replace(r'^\s*$', np.nan, regex=True)

# %%
#Convert to datetime
df['ReleaseDate'] = pd.to_datetime(df['ReleaseDate'])

# %%
#check data type
df['ReleaseDate'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.describe()
# Out:
#         Metacritic  RequiredAge    DemoCount  DeveloperCount     DLCCount  \
# count  2235.000000  2235.000000  2235.000000     2235.000000  2235.000000
# mean     72.008501     2.508277     0.186577        1.087696     1.502013
# std      11.152135     5.984335     0.391950        0.362037     5.995998
# min      20.000000     0.000000     0.000000        0.000000     0.000000
# 25%      66.000000     0.000000     0.000000        1.000000     0.000000
# 50%      73.000000     0.000000     0.000000        1.000000     0.000000
# 75%      80.000000     0.000000     0.000000        1.000000     1.000000
# max      96.000000    18.000000     2.000000        5.000000   169.000000
#
#         MovieCount  PackageCount  RecommendationCount  ScreenshotCount  \
# count  2235.000000   2235.000000         2.235000e+03      2235.000000
# mean      1.798210      1.680984         4.552546e+03        11.968680
# std       1.829089      1.023349         3.541729e+04         7.336697
# min       0.000000      0.000000         0.000000e+00         2.000000
# 25%       1.000000      1.000000         1.370000e+02         8.000000
# 50%       1.000000      1.000000         5.180000e+02        10.000000
# 75%       2.000000      2.000000         2.118500e+03        14.000000
# max      20.000000     11.000000         1.427633e+06       114.000000
#
#        SteamSpyOwners  ...      Finnish    Ukrainian     Romanian  \
# count    2.235000e+03  ...  2235.000000  2235.000000  2235.000000
# mean     5.867512e+05  ...     0.027740     0.015660     0.013870
# std      2.455699e+06  ...     0.164265     0.124184     0.116979
# min      0.000000e+00  ...     0.000000     0.000000     0.000000
# 25%      3.560100e+04  ...     0.000000     0.000000     0.000000
# 50%      1.303870e+05  ...     0.000000     0.000000     0.000000
# 75%      4.602110e+05  ...     0.000000     0.000000     0.000000
# max      9.068758e+07  ...     1.000000     1.000000     1.000000
#
#               Thai        Greek    Bulgarian       Arabic    Slovakian  \
# count  2235.000000  2235.000000  2235.000000  2235.000000  2235.000000
# mean      0.008949     0.008949     0.008949     0.008501     0.000447
# std       0.094194     0.094194     0.094194     0.091829     0.021152
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        num_lang_audio_support  num_languages
# count             2235.000000    2235.000000
# mean                 1.216555       4.945861
# std                  2.172011       4.165792
# min                  0.000000       1.000000
# 25%                  0.000000       1.000000
# 50%                  0.000000       5.000000
# 75%                  1.000000       7.000000
# max                 27.000000      27.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# # Creating Metacritic Binary Variable

# %%
#plot metacritic values
plt.hist(df['Metacritic'], bins=100)
plt.axvline(x=80, color='red')
plt.axvline(x=65, color='red')
plt.xlabel("Metacritic Score")
plt.ylabel("Frequency")
plt.title("Histogram of Metacritic Score")
# Out:
# Text(0.5, 1.0, 'Histogram of Metacritic Score')

# %%
#set positive to 1, negative to 0, and neutral to -1 (will be dropped later)
conditions = [(df['Metacritic']<=65),
              (df['Metacritic']>65)&(df['Metacritic']<80),
              (df['Metacritic']>=80)
             ]
choices = [0, -1, 1]
df['Metacritic_binary'] = np.select(conditions, choices, default=-1)

# %%
df[['Metacritic', 'Metacritic_binary']].head(100)
# Out:
#      Metacritic  Metacritic_binary
# 0            88                  1
# 2            79                 -1
# 6            96                  1
# 7            65                  0
# 9            71                 -1
# 10           96                  1
# 11           88                  1
# 13           80                  1
# 17           87                  1
# 18           90                  1
# 19           90                  1
# 20           92                  1
# 21           89                  1
# 22           89                  1
# 23           90                  1
# 24           95                  1
# 25           77                 -1
# 27           83                  1
# 28           69                 -1
# 29           81                  1
# 30           72                 -1
# 31           75                 -1
# 34           84                  1
# 35           75                 -1
# 36           84                  1
# 37           76                 -1
# 38           82                  1
# 39           79                 -1
# 41           80                  1
# 42           84                  1
# 43           56                  0
# 44           68                 -1
# 45           77                 -1
# 47           73                 -1
# 48           65                  0
# 49           72                 -1
# 52           81                  1
# 56           83                  1
# 57           94                  1
# 61           69                 -1
# 65           76                 -1
# 67           73                 -1
# 68           74                 -1
# 69           69                 -1
# 74           61                  0
# 75           59                  0
# 76           80                  1
# 77           76                 -1
# 78           91                  1
# 79           86                  1
# 80           87                  1
# 81           81                  1
# 82           82                  1
# 84           74                 -1
# 85           72                 -1
# 86           71                 -1
# 87           73                 -1
# 88           67                 -1
# 90           33                  0
# 93           84                  1
# 94           76                 -1
# 96           82                  1
# 97           72                 -1
# 99           77                 -1
# 100          82                  1
# 101          81                  1
# 102          57                  0
# 103          69                 -1
# 104          65                  0
# 128          76                 -1
# 129          78                 -1
# 132          87                  1
# 135          78                 -1
# 136          76                 -1
# 137          55                  0
# 138          75                 -1
# 140          70                 -1
# 141          65                  0
# 142          67                 -1
# 143          87                  1
# 144          94                  1
# 145          90                  1
# 146          88                  1
# 147          67                 -1
# 148          67                 -1
# 149          84                  1
# 155          80                  1
# 156          62                  0
# 159          82                  1
# 160          80                  1
# 161          70                 -1
# 162          77                 -1
# 163          80                  1
# 164          93                  1
# 165          86                  1
# 166          87                  1
# 167          88                  1
# 168          78                 -1
# 169          92                  1
# 170          79                 -1

# %%
#check for equal distribution of pos and neg
plt.hist(df['Metacritic_binary'])
plt.xlabel("Metacritic Score")
plt.ylabel("Frequency")
plt.title("Bar Plot of Categorized Metacritic Score")
# Out:
# Text(0.5, 1.0, 'Bar Plot of Categorized Metacritic Score')

# %% [markdown]
# # Logistic Regression Model

# %%
#select columns to work with for logistic regression
df_lr = df[['Metacritic_binary', 'GenreIsNonGame', 'GenreIsIndie',
       'GenreIsAction', 'GenreIsAdventure', 'GenreIsCasual', 'GenreIsStrategy',
       'GenreIsRPG', 'GenreIsSimulation', 'GenreIsEarlyAccess',
       'GenreIsFreeToPlay', 'GenreIsSports', 'GenreIsRacing',
       'CategorySinglePlayer', 'CategoryMultiplayer', 'CategoryCoop',
       'CategoryMMO', 'CategoryInAppPurchase', 'CategoryIncludeSrcSDK',
       'CategoryIncludeLevelEditor', 'CategoryVRSupport', 'PlatformWindows',
       'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin', 'PCReqsHaveRec',
       'LinuxReqsHaveMin', 'LinuxReqsHaveRec', 'MacReqsHaveMin',
       'MacReqsHaveRec', 'RequiredAge', 'DemoCount', 'DeveloperCount',
       'DLCCount', 'MovieCount', 'PackageCount', 'RecommendationCount',
       'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
       'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
       'AchievementCount', 'ControllerSupport', 'FreeVerAvail',
       'PurchaseAvail', 'SubscriptionAvail', 'PriceFinal', 'ReleaseDate',
       'English', 'German', 'French', 'Spanish', 'Italian', 'Russian',
       'Polish', 'Japanese', 'Portuguese-Brazil', 'Czech', 'Korean',
       'Simplified Chinese', 'Dutch', 'Traditional Chinese', 'Portuguese',
       'Hungarian', 'Turkish', 'Swedish', 'Danish', 'Norwegian', 'Finnish',
       'Ukrainian', 'Romanian', 'Thai', 'Greek', 'Bulgarian', 'Arabic',
       'Slovakian', 'num_lang_audio_support']]

# %%
#Drop NAs
df_lr = df_lr.dropna()

#Drop neutral metacritic values
df_lr = df_lr[df_lr['Metacritic_binary'] >= 0]

df_lr.head()
# Out:
#     Metacritic_binary  GenreIsNonGame  GenreIsIndie  GenreIsAction  \
# 0                   1           False         False           True
# 6                   1           False         False           True
# 7                   0           False         False           True
# 10                  1           False         False           True
# 11                  1           False         False           True
#
#     GenreIsAdventure  GenreIsCasual  GenreIsStrategy  GenreIsRPG  \
# 0              False          False            False       False
# 6              False          False            False       False
# 7              False          False            False       False
# 10             False          False            False       False
# 11             False          False            False       False
#
#     GenreIsSimulation  GenreIsEarlyAccess  ...  Norwegian  Finnish  Ukrainian  \
# 0               False               False  ...          0        0          0
# 6               False               False  ...          0        0          0
# 7               False               False  ...          0        0          0
# 10              False               False  ...          1        1          0
# 11              False               False  ...          0        0          0
#
#     Romanian  Thai  Greek  Bulgarian  Arabic  Slovakian  \
# 0          0     0      0          0       0          0
# 6          0     0      0          0       0          0
# 7          0     0      0          0       0          0
# 10         0     1      0          0       0          0
# 11         0     1      0          0       0          0
#
#     num_lang_audio_support
# 0                      0.0
# 6                      0.0
# 7                      0.0
# 10                    10.0
# 11                     0.0
#
# [5 rows x 78 columns]

# %%
#make columns for month and year, drop date column
now = pd.to_datetime('now')
df_lr['Age']=(now - df_lr['ReleaseDate']).dt.total_seconds() / (60*60*24*365.25)
df_lr['Month'] = df_lr['ReleaseDate'].dt.month_name()
df_lr=df_lr.drop('ReleaseDate', axis=1)

# %%
#Make dummy variables for months
df_lr = pd.concat([df_lr, pd.get_dummies(df_lr['Month'])], axis=1)
df_lr = df_lr.drop('Month', axis=1)

# %%
#Make booleans numeric
df_lr=df_lr.replace({True: 1, False: 0})

# %%
#Shuffle rows
df_lr_shuffled= df_lr.sample(frac=1, random_state=1).reset_index()
df_lr_shuffled.shape
# Out:
# (1144, 91)

# %%
# select features for training
features = ['GenreIsNonGame', 'GenreIsIndie', 'GenreIsAction',
        'GenreIsAdventure', 'GenreIsCasual', 'GenreIsStrategy', 'GenreIsRPG',
        'GenreIsSimulation', 'GenreIsEarlyAccess', 'GenreIsFreeToPlay',
        'GenreIsSports', 'GenreIsRacing', 'CategorySinglePlayer',
        'CategoryMultiplayer', 'CategoryCoop', 'CategoryMMO',
        'CategoryInAppPurchase', 'CategoryIncludeSrcSDK',
        'CategoryIncludeLevelEditor', 'CategoryVRSupport', 'PlatformWindows',
        'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin', 'PCReqsHaveRec',
        'LinuxReqsHaveMin', 'LinuxReqsHaveRec', 'MacReqsHaveMin',
        'MacReqsHaveRec', 'RequiredAge', 'DemoCount', 'DeveloperCount',
        'DLCCount', 'MovieCount', 'PackageCount', 'RecommendationCount',
        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
        'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
        'AchievementCount', 'ControllerSupport', 'FreeVerAvail',
        'PurchaseAvail', 'SubscriptionAvail', 'PriceFinal', 'English', 'German',
        'French', 'Spanish', 'Italian', 'Russian', 'Polish', 'Japanese',
        'Portuguese-Brazil', 'Czech', 'Korean', 'Simplified Chinese', 'Dutch',
        'Traditional Chinese', 'Portuguese', 'Hungarian', 'Turkish', 'Swedish',
        'Danish', 'Norwegian', 'Finnish', 'Ukrainian', 'Romanian', 'Thai',
        'Greek', 'Bulgarian', 'Arabic', 'Slovakian', 'num_lang_audio_support',
         'April', 'August', 'December', 'February', 'January', 'July',
        'June', 'March', 'May', 'November', 'October', 'September','Age']

# Use a ~80/20 train/test split.
lr_train = df_lr_shuffled[:944]
lr_test = df_lr_shuffled[944:]

# Create separate variables for features (inputs) and labels (outputs).
# We will be using these in the cells below.
X_train = lr_train[features].values
X_test = lr_test[features].values
y_train = lr_train['Metacritic_binary'].values
y_test = lr_test['Metacritic_binary'].values

# Confirm the data shapes are as expected.
print('train data shape:', X_train.shape)
print('train labels shape:', y_train.shape)
print('test data shape:', X_test.shape)
print('test labels shape:', y_test.shape)
# Out:
# train data shape: (944, 89)
# train labels shape: (944,)
# test data shape: (200, 89)
# test labels shape: (200,)

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
print(X_train_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (944, 89)
# (200, 89)

# %%
from tensorflow.keras import initializers

def build_model(num_features):
    """Return a simple linear regression model using the Keras Sequential API."""
  # Clear session and set a random seed for consistent behavior.
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)

  # Use Keras Sequential API to build a linear regression model.
    model = tf.keras.Sequential()
    
    # create input layer
    model.add(tf.keras.Input(shape=(num_features,),
         name='Input'
    ))
    
    # create output layer
    model.add(tf.keras.layers.Dense(
        units=1,                    # there is a single output
        use_bias=True,               # include a learned bias parameter
        activation = 'sigmoid',          # Logistic regression
        kernel_initializer=initializers.RandomNormal(stddev=0.01),
        bias_initializer=initializers.RandomNormal(stddev=0.01),
        name="Output"
      ))

  # Use cross entropy as our loss and the Adam optimizer.
    model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.005), 
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    )
    
    return model

# Build a model
model = build_model(num_features=X_train_scaled.shape[1])

# %%
history = model.fit(
  x = X_train_scaled,
  y = y_train,
  epochs=20,
  batch_size=50,
  validation_split=0.1,
  verbose=1
)

# grab history
history = history.history

# plot loss for train and validation
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=2, color='darkgoldenrod')
plt.plot(history['val_binary_accuracy'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Accuracy');
# Out:
# Epoch 1/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6903 - binary_accuracy: 0.5253 - val_loss: 0.6859 - val_binary_accuracy: 0.6105
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6759 - binary_accuracy: 0.6243 - val_loss: 0.6731 - val_binary_accuracy: 0.6316
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6640 - binary_accuracy: 0.6726 - val_loss: 0.6624 - val_binary_accuracy: 0.6526
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6541 - binary_accuracy: 0.6843 - val_loss: 0.6535 - val_binary_accuracy: 0.6842
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6452 - binary_accuracy: 0.6938 - val_loss: 0.6458 - val_binary_accuracy: 0.6947
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6375 - binary_accuracy: 0.7055 - val_loss: 0.6392 - val_binary_accuracy: 0.6947
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6304 - binary_accuracy: 0.7126 - val_loss: 0.6334 - val_binary_accuracy: 0.6947
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6240 - binary_accuracy: 0.7150 - val_loss: 0.6284 - val_binary_accuracy: 0.6947
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6181 - binary_accuracy: 0.7208 - val_loss: 0.6238 - val_binary_accuracy: 0.6947
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6127 - binary_accuracy: 0.7267 - val_loss: 0.6197 - val_binary_accuracy: 0.6947
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6077 - binary_accuracy: 0.7291 - val_loss: 0.6160 - val_binary_accuracy: 0.7053
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6030 - binary_accuracy: 0.7326 - val_loss: 0.6127 - val_binary_accuracy: 0.7053
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5986 - binary_accuracy: 0.7397 - val_loss: 0.6097 - val_binary_accuracy: 0.7158
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5946 - binary_accuracy: 0.7397 - val_loss: 0.6069 - val_binary_accuracy: 0.7368
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5907 - binary_accuracy: 0.7397 - val_loss: 0.6044 - val_binary_accuracy: 0.7368
# Epoch 16/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5872 - binary_accuracy: 0.7432 - val_loss: 0.6020 - val_binary_accuracy: 0.7579
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5839 - binary_accuracy: 0.7444 - val_loss: 0.5998 - val_binary_accuracy: 0.7579
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5807 - binary_accuracy: 0.7444 - val_loss: 0.5979 - val_binary_accuracy: 0.7579
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5776 - binary_accuracy: 0.7479 - val_loss: 0.5961 - val_binary_accuracy: 0.7579
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5747 - binary_accuracy: 0.7503 - val_loss: 0.5944 - val_binary_accuracy: 0.7579

# %% [markdown]
# ## Experiments

# %%
from tensorflow.keras import initializers

#Experimenting with SGD optimizer
def build_model(num_features):
    """Return a simple linear regression model using the Keras Sequential API."""
  # Clear session and set a random seed for consistent behavior.
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)

  # Use Keras Sequential API to build a logistic regression model.
    model = tf.keras.Sequential()
    
    # create input layer
    model.add(tf.keras.Input(shape=(num_features,),
         name='Input'
    ))
    
    # create output layer
    model.add(tf.keras.layers.Dense(
        units=1,                    # there is a single output
        use_bias=True,               # include a learned bias parameter
        activation = 'sigmoid',          # Logistic regression
        #kernel_initializer=initializers.RandomNormal(stddev=0.01),
        #bias_initializer=initializers.RandomNormal(stddev=0.01),
        name="Output"
      ))

  # Use cross entropy as our loss and the SGD optimizer.
    model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.005), 
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    )
    
    return model

# Build a model
model = build_model(num_features=X_train_scaled.shape[1])

history = model.fit(
  x = X_train_scaled,
  y = y_train,
  epochs=20,
  batch_size=50,
  validation_split=0.1,
  verbose=1
)

# grab history
history = history.history

# plot loss for train and validation
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=2, color='darkgoldenrod')
plt.plot(history['val_binary_accuracy'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Accuracy');
# Out:
# Epoch 1/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9357 - binary_accuracy: 0.4582 - val_loss: 0.7800 - val_binary_accuracy: 0.5053
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.9054 - binary_accuracy: 0.4759 - val_loss: 0.7586 - val_binary_accuracy: 0.5158
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.8782 - binary_accuracy: 0.4794 - val_loss: 0.7398 - val_binary_accuracy: 0.5158
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.8542 - binary_accuracy: 0.4900 - val_loss: 0.7233 - val_binary_accuracy: 0.5263
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.8325 - binary_accuracy: 0.5018 - val_loss: 0.7089 - val_binary_accuracy: 0.5263
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.8133 - binary_accuracy: 0.5124 - val_loss: 0.6961 - val_binary_accuracy: 0.5579
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7957 - binary_accuracy: 0.5206 - val_loss: 0.6848 - val_binary_accuracy: 0.5895
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7796 - binary_accuracy: 0.5383 - val_loss: 0.6748 - val_binary_accuracy: 0.5895
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7647 - binary_accuracy: 0.5430 - val_loss: 0.6657 - val_binary_accuracy: 0.6000
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7511 - binary_accuracy: 0.5524 - val_loss: 0.6576 - val_binary_accuracy: 0.6105
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7385 - binary_accuracy: 0.5571 - val_loss: 0.6504 - val_binary_accuracy: 0.6211
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7267 - binary_accuracy: 0.5642 - val_loss: 0.6438 - val_binary_accuracy: 0.6211
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7158 - binary_accuracy: 0.5748 - val_loss: 0.6379 - val_binary_accuracy: 0.6105
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7056 - binary_accuracy: 0.5842 - val_loss: 0.6325 - val_binary_accuracy: 0.6211
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6960 - binary_accuracy: 0.5866 - val_loss: 0.6276 - val_binary_accuracy: 0.6105
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6871 - binary_accuracy: 0.5901 - val_loss: 0.6232 - val_binary_accuracy: 0.6105
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6788 - binary_accuracy: 0.6007 - val_loss: 0.6192 - val_binary_accuracy: 0.6105
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6709 - binary_accuracy: 0.6054 - val_loss: 0.6156 - val_binary_accuracy: 0.6105
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6636 - binary_accuracy: 0.6160 - val_loss: 0.6122 - val_binary_accuracy: 0.6211
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6566 - binary_accuracy: 0.6266 - val_loss: 0.6092 - val_binary_accuracy: 0.6316

# %%
from tensorflow.keras import initializers

#Experimenting with Adam optimizer
def build_model(num_features):
    """Return a simple linear regression model using the Keras Sequential API."""
  # Clear session and set a random seed for consistent behavior.
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)

  # Use Keras Sequential API to build a logistic regression model.
    model = tf.keras.Sequential()
    
    # create input layer
    model.add(tf.keras.Input(shape=(num_features,),
         name='Input'
    ))
    
    # create output layer
    model.add(tf.keras.layers.Dense(
        units=1,                    # there is a single output
        use_bias=True,               # include a learned bias parameter
        activation = 'sigmoid',          # Logistic regression
        kernel_initializer=initializers.RandomNormal(stddev=0.01),
        bias_initializer=initializers.RandomNormal(stddev=0.01),
        name="Output"
      ))

  # Use cross entropy as our loss and the Adam optimizer.
    model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.005), 
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    )
    
    return model

# Build a model
model = build_model(num_features=X_train_scaled.shape[1])

history = model.fit(
  x = X_train_scaled,
  y = y_train,
  epochs=200,
  batch_size=50,
  validation_split=0.1,
  verbose=1
)

# grab history
history = history.history

# plot loss for train and validation
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=2, color='darkgoldenrod')
plt.plot(history['val_binary_accuracy'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Accuracy');
# Out:
# Epoch 1/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6550 - binary_accuracy: 0.6360 - val_loss: 0.6091 - val_binary_accuracy: 0.7158
# Epoch 2/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5892 - binary_accuracy: 0.7102 - val_loss: 0.5919 - val_binary_accuracy: 0.7263
# Epoch 3/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5578 - binary_accuracy: 0.7373 - val_loss: 0.5832 - val_binary_accuracy: 0.7053
# Epoch 4/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5367 - binary_accuracy: 0.7515 - val_loss: 0.5737 - val_binary_accuracy: 0.7263
# Epoch 5/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5230 - binary_accuracy: 0.7633 - val_loss: 0.5778 - val_binary_accuracy: 0.7368
# Epoch 6/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5143 - binary_accuracy: 0.7621 - val_loss: 0.5697 - val_binary_accuracy: 0.7368
# Epoch 7/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5083 - binary_accuracy: 0.7668 - val_loss: 0.5712 - val_binary_accuracy: 0.7158
# Epoch 8/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5020 - binary_accuracy: 0.7691 - val_loss: 0.5720 - val_binary_accuracy: 0.7368
# Epoch 9/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4983 - binary_accuracy: 0.7633 - val_loss: 0.5734 - val_binary_accuracy: 0.7474
# Epoch 10/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4961 - binary_accuracy: 0.7656 - val_loss: 0.5725 - val_binary_accuracy: 0.7368
# Epoch 11/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4917 - binary_accuracy: 0.7691 - val_loss: 0.5732 - val_binary_accuracy: 0.7474
# Epoch 12/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4895 - binary_accuracy: 0.7786 - val_loss: 0.5736 - val_binary_accuracy: 0.7263
# Epoch 13/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4876 - binary_accuracy: 0.7750 - val_loss: 0.5710 - val_binary_accuracy: 0.7474
# Epoch 14/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4857 - binary_accuracy: 0.7786 - val_loss: 0.5714 - val_binary_accuracy: 0.7368
# Epoch 15/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4850 - binary_accuracy: 0.7774 - val_loss: 0.5718 - val_binary_accuracy: 0.7368
# Epoch 16/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4825 - binary_accuracy: 0.7797 - val_loss: 0.5732 - val_binary_accuracy: 0.7368
# Epoch 17/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4825 - binary_accuracy: 0.7762 - val_loss: 0.5714 - val_binary_accuracy: 0.7368
# Epoch 18/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4817 - binary_accuracy: 0.7739 - val_loss: 0.5685 - val_binary_accuracy: 0.7368
# Epoch 19/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4809 - binary_accuracy: 0.7845 - val_loss: 0.5754 - val_binary_accuracy: 0.7474
# Epoch 20/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4799 - binary_accuracy: 0.7762 - val_loss: 0.5780 - val_binary_accuracy: 0.7368
# Epoch 21/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4785 - binary_accuracy: 0.7774 - val_loss: 0.5711 - val_binary_accuracy: 0.7368
# Epoch 22/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4779 - binary_accuracy: 0.7762 - val_loss: 0.5733 - val_binary_accuracy: 0.7368
# Epoch 23/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4776 - binary_accuracy: 0.7797 - val_loss: 0.5711 - val_binary_accuracy: 0.7368
# Epoch 24/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4778 - binary_accuracy: 0.7750 - val_loss: 0.5733 - val_binary_accuracy: 0.7368
# Epoch 25/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4768 - binary_accuracy: 0.7809 - val_loss: 0.5759 - val_binary_accuracy: 0.7368
# Epoch 26/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4756 - binary_accuracy: 0.7797 - val_loss: 0.5711 - val_binary_accuracy: 0.7474
# Epoch 27/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4766 - binary_accuracy: 0.7762 - val_loss: 0.5775 - val_binary_accuracy: 0.7474
# Epoch 28/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4762 - binary_accuracy: 0.7750 - val_loss: 0.5734 - val_binary_accuracy: 0.7474
# Epoch 29/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4753 - binary_accuracy: 0.7833 - val_loss: 0.5742 - val_binary_accuracy: 0.7474
# Epoch 30/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4749 - binary_accuracy: 0.7774 - val_loss: 0.5762 - val_binary_accuracy: 0.7474
# Epoch 31/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4757 - binary_accuracy: 0.7833 - val_loss: 0.5772 - val_binary_accuracy: 0.7474
# Epoch 32/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4745 - binary_accuracy: 0.7797 - val_loss: 0.5714 - val_binary_accuracy: 0.7579
# Epoch 33/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4741 - binary_accuracy: 0.7786 - val_loss: 0.5749 - val_binary_accuracy: 0.7474
# Epoch 34/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4735 - binary_accuracy: 0.7797 - val_loss: 0.5734 - val_binary_accuracy: 0.7474
# Epoch 35/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4744 - binary_accuracy: 0.7786 - val_loss: 0.5723 - val_binary_accuracy: 0.7579
# Epoch 36/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4739 - binary_accuracy: 0.7774 - val_loss: 0.5766 - val_binary_accuracy: 0.7579
# Epoch 37/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4733 - binary_accuracy: 0.7797 - val_loss: 0.5757 - val_binary_accuracy: 0.7579
# Epoch 38/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4732 - binary_accuracy: 0.7797 - val_loss: 0.5725 - val_binary_accuracy: 0.7474
# Epoch 39/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4739 - binary_accuracy: 0.7821 - val_loss: 0.5775 - val_binary_accuracy: 0.7474
# Epoch 40/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4728 - binary_accuracy: 0.7786 - val_loss: 0.5710 - val_binary_accuracy: 0.7684
# Epoch 41/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4724 - binary_accuracy: 0.7797 - val_loss: 0.5758 - val_binary_accuracy: 0.7474
# Epoch 42/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4737 - binary_accuracy: 0.7762 - val_loss: 0.5722 - val_binary_accuracy: 0.7368
# Epoch 43/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4722 - binary_accuracy: 0.7762 - val_loss: 0.5731 - val_binary_accuracy: 0.7474
# Epoch 44/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4729 - binary_accuracy: 0.7739 - val_loss: 0.5751 - val_binary_accuracy: 0.7474
# Epoch 45/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4725 - binary_accuracy: 0.7750 - val_loss: 0.5700 - val_binary_accuracy: 0.7684
# Epoch 46/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4726 - binary_accuracy: 0.7774 - val_loss: 0.5697 - val_binary_accuracy: 0.7474
# Epoch 47/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4729 - binary_accuracy: 0.7809 - val_loss: 0.5733 - val_binary_accuracy: 0.7474
# Epoch 48/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4725 - binary_accuracy: 0.7809 - val_loss: 0.5710 - val_binary_accuracy: 0.7684
# Epoch 49/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7833 - val_loss: 0.5687 - val_binary_accuracy: 0.7579
# Epoch 50/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4716 - binary_accuracy: 0.7762 - val_loss: 0.5705 - val_binary_accuracy: 0.7579
# Epoch 51/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4720 - binary_accuracy: 0.7739 - val_loss: 0.5756 - val_binary_accuracy: 0.7579
# Epoch 52/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4728 - binary_accuracy: 0.7786 - val_loss: 0.5725 - val_binary_accuracy: 0.7474
# Epoch 53/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4720 - binary_accuracy: 0.7856 - val_loss: 0.5723 - val_binary_accuracy: 0.7474
# Epoch 54/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7797 - val_loss: 0.5704 - val_binary_accuracy: 0.7579
# Epoch 55/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7786 - val_loss: 0.5670 - val_binary_accuracy: 0.7474
# Epoch 56/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4721 - binary_accuracy: 0.7809 - val_loss: 0.5662 - val_binary_accuracy: 0.7684
# Epoch 57/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4719 - binary_accuracy: 0.7868 - val_loss: 0.5683 - val_binary_accuracy: 0.7579
# Epoch 58/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4707 - binary_accuracy: 0.7762 - val_loss: 0.5742 - val_binary_accuracy: 0.7579
# Epoch 59/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7809 - val_loss: 0.5694 - val_binary_accuracy: 0.7579
# Epoch 60/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4706 - binary_accuracy: 0.7809 - val_loss: 0.5662 - val_binary_accuracy: 0.7789
# Epoch 61/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4709 - binary_accuracy: 0.7739 - val_loss: 0.5721 - val_binary_accuracy: 0.7474
# Epoch 62/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4717 - binary_accuracy: 0.7739 - val_loss: 0.5697 - val_binary_accuracy: 0.7579
# Epoch 63/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4712 - binary_accuracy: 0.7774 - val_loss: 0.5635 - val_binary_accuracy: 0.7789
# Epoch 64/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7786 - val_loss: 0.5661 - val_binary_accuracy: 0.7789
# Epoch 65/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4701 - binary_accuracy: 0.7774 - val_loss: 0.5641 - val_binary_accuracy: 0.7579
# Epoch 66/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7762 - val_loss: 0.5659 - val_binary_accuracy: 0.7684
# Epoch 67/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4702 - binary_accuracy: 0.7786 - val_loss: 0.5671 - val_binary_accuracy: 0.7684
# Epoch 68/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4704 - binary_accuracy: 0.7786 - val_loss: 0.5663 - val_binary_accuracy: 0.7474
# Epoch 69/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4705 - binary_accuracy: 0.7762 - val_loss: 0.5652 - val_binary_accuracy: 0.7684
# Epoch 70/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4699 - binary_accuracy: 0.7762 - val_loss: 0.5615 - val_binary_accuracy: 0.7684
# Epoch 71/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4694 - binary_accuracy: 0.7797 - val_loss: 0.5625 - val_binary_accuracy: 0.7789
# Epoch 72/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4714 - binary_accuracy: 0.7774 - val_loss: 0.5614 - val_binary_accuracy: 0.7789
# Epoch 73/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7786 - val_loss: 0.5622 - val_binary_accuracy: 0.7684
# Epoch 74/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4706 - binary_accuracy: 0.7750 - val_loss: 0.5601 - val_binary_accuracy: 0.7684
# Epoch 75/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4701 - binary_accuracy: 0.7739 - val_loss: 0.5670 - val_binary_accuracy: 0.7474
# Epoch 76/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4709 - binary_accuracy: 0.7739 - val_loss: 0.5616 - val_binary_accuracy: 0.7895
# Epoch 77/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7821 - val_loss: 0.5669 - val_binary_accuracy: 0.7579
# Epoch 78/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4700 - binary_accuracy: 0.7786 - val_loss: 0.5644 - val_binary_accuracy: 0.7579
# Epoch 79/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4707 - binary_accuracy: 0.7797 - val_loss: 0.5608 - val_binary_accuracy: 0.7789
# Epoch 80/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7762 - val_loss: 0.5600 - val_binary_accuracy: 0.7579
# Epoch 81/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4699 - binary_accuracy: 0.7786 - val_loss: 0.5643 - val_binary_accuracy: 0.7474
# Epoch 82/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4695 - binary_accuracy: 0.7750 - val_loss: 0.5609 - val_binary_accuracy: 0.7579
# Epoch 83/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7797 - val_loss: 0.5659 - val_binary_accuracy: 0.7579
# Epoch 84/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7786 - val_loss: 0.5593 - val_binary_accuracy: 0.7474
# Epoch 85/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4690 - binary_accuracy: 0.7833 - val_loss: 0.5579 - val_binary_accuracy: 0.7579
# Epoch 86/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4699 - binary_accuracy: 0.7821 - val_loss: 0.5561 - val_binary_accuracy: 0.7789
# Epoch 87/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4700 - binary_accuracy: 0.7750 - val_loss: 0.5601 - val_binary_accuracy: 0.7579
# Epoch 88/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7750 - val_loss: 0.5635 - val_binary_accuracy: 0.7474
# Epoch 89/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4695 - binary_accuracy: 0.7774 - val_loss: 0.5568 - val_binary_accuracy: 0.7789
# Epoch 90/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4687 - binary_accuracy: 0.7809 - val_loss: 0.5600 - val_binary_accuracy: 0.7579
# Epoch 91/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4694 - binary_accuracy: 0.7809 - val_loss: 0.5572 - val_binary_accuracy: 0.7684
# Epoch 92/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4695 - binary_accuracy: 0.7750 - val_loss: 0.5570 - val_binary_accuracy: 0.7684
# Epoch 93/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4698 - binary_accuracy: 0.7739 - val_loss: 0.5633 - val_binary_accuracy: 0.7368
# Epoch 94/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7809 - val_loss: 0.5509 - val_binary_accuracy: 0.7895
# Epoch 95/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7786 - val_loss: 0.5563 - val_binary_accuracy: 0.7579
# Epoch 96/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7821 - val_loss: 0.5537 - val_binary_accuracy: 0.7579
# Epoch 97/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7750 - val_loss: 0.5533 - val_binary_accuracy: 0.7895
# Epoch 98/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7774 - val_loss: 0.5545 - val_binary_accuracy: 0.7579
# Epoch 99/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4692 - binary_accuracy: 0.7845 - val_loss: 0.5512 - val_binary_accuracy: 0.7579
# Epoch 100/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4687 - binary_accuracy: 0.7821 - val_loss: 0.5547 - val_binary_accuracy: 0.7789
# Epoch 101/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4687 - binary_accuracy: 0.7809 - val_loss: 0.5543 - val_binary_accuracy: 0.7684
# Epoch 102/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7727 - val_loss: 0.5534 - val_binary_accuracy: 0.7579
# Epoch 103/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4692 - binary_accuracy: 0.7774 - val_loss: 0.5556 - val_binary_accuracy: 0.7579
# Epoch 104/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7750 - val_loss: 0.5554 - val_binary_accuracy: 0.7684
# Epoch 105/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7762 - val_loss: 0.5538 - val_binary_accuracy: 0.7684
# Epoch 106/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4690 - binary_accuracy: 0.7786 - val_loss: 0.5520 - val_binary_accuracy: 0.7789
# Epoch 107/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4686 - binary_accuracy: 0.7786 - val_loss: 0.5490 - val_binary_accuracy: 0.7684
# Epoch 108/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4683 - binary_accuracy: 0.7774 - val_loss: 0.5526 - val_binary_accuracy: 0.7474
# Epoch 109/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7821 - val_loss: 0.5499 - val_binary_accuracy: 0.7579
# Epoch 110/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4673 - binary_accuracy: 0.7786 - val_loss: 0.5500 - val_binary_accuracy: 0.7789
# Epoch 111/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4693 - binary_accuracy: 0.7774 - val_loss: 0.5511 - val_binary_accuracy: 0.7684
# Epoch 112/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7762 - val_loss: 0.5405 - val_binary_accuracy: 0.8000
# Epoch 113/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4697 - binary_accuracy: 0.7845 - val_loss: 0.5535 - val_binary_accuracy: 0.7684
# Epoch 114/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7809 - val_loss: 0.5467 - val_binary_accuracy: 0.7895
# Epoch 115/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4680 - binary_accuracy: 0.7762 - val_loss: 0.5512 - val_binary_accuracy: 0.7579
# Epoch 116/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4675 - binary_accuracy: 0.7762 - val_loss: 0.5493 - val_binary_accuracy: 0.7684
# Epoch 117/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7797 - val_loss: 0.5466 - val_binary_accuracy: 0.7579
# Epoch 118/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4675 - binary_accuracy: 0.7774 - val_loss: 0.5474 - val_binary_accuracy: 0.7684
# Epoch 119/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7797 - val_loss: 0.5467 - val_binary_accuracy: 0.7789
# Epoch 120/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4672 - binary_accuracy: 0.7833 - val_loss: 0.5487 - val_binary_accuracy: 0.7684
# Epoch 121/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4678 - binary_accuracy: 0.7845 - val_loss: 0.5441 - val_binary_accuracy: 0.7789
# Epoch 122/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4676 - binary_accuracy: 0.7809 - val_loss: 0.5466 - val_binary_accuracy: 0.7684
# Epoch 123/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4682 - binary_accuracy: 0.7809 - val_loss: 0.5466 - val_binary_accuracy: 0.7684
# Epoch 124/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4679 - binary_accuracy: 0.7774 - val_loss: 0.5445 - val_binary_accuracy: 0.7789
# Epoch 125/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4681 - binary_accuracy: 0.7786 - val_loss: 0.5472 - val_binary_accuracy: 0.7684
# Epoch 126/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4686 - binary_accuracy: 0.7821 - val_loss: 0.5481 - val_binary_accuracy: 0.7474
# Epoch 127/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4673 - binary_accuracy: 0.7821 - val_loss: 0.5464 - val_binary_accuracy: 0.7684
# Epoch 128/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4678 - binary_accuracy: 0.7750 - val_loss: 0.5492 - val_binary_accuracy: 0.7684
# Epoch 129/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4678 - binary_accuracy: 0.7797 - val_loss: 0.5413 - val_binary_accuracy: 0.7684
# Epoch 130/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4665 - binary_accuracy: 0.7845 - val_loss: 0.5415 - val_binary_accuracy: 0.7789
# Epoch 131/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4670 - binary_accuracy: 0.7786 - val_loss: 0.5403 - val_binary_accuracy: 0.7789
# Epoch 132/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4681 - binary_accuracy: 0.7750 - val_loss: 0.5444 - val_binary_accuracy: 0.7684
# Epoch 133/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7774 - val_loss: 0.5413 - val_binary_accuracy: 0.7789
# Epoch 134/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4681 - binary_accuracy: 0.7809 - val_loss: 0.5376 - val_binary_accuracy: 0.7684
# Epoch 135/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7809 - val_loss: 0.5457 - val_binary_accuracy: 0.7579
# Epoch 136/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4671 - binary_accuracy: 0.7762 - val_loss: 0.5460 - val_binary_accuracy: 0.7684
# Epoch 137/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4663 - binary_accuracy: 0.7762 - val_loss: 0.5416 - val_binary_accuracy: 0.7684
# Epoch 138/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4676 - binary_accuracy: 0.7786 - val_loss: 0.5354 - val_binary_accuracy: 0.7895
# Epoch 139/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5396 - val_binary_accuracy: 0.7684
# Epoch 140/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4670 - binary_accuracy: 0.7809 - val_loss: 0.5444 - val_binary_accuracy: 0.7684
# Epoch 141/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4675 - binary_accuracy: 0.7750 - val_loss: 0.5436 - val_binary_accuracy: 0.7684
# Epoch 142/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4686 - binary_accuracy: 0.7762 - val_loss: 0.5380 - val_binary_accuracy: 0.7789
# Epoch 143/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7833 - val_loss: 0.5417 - val_binary_accuracy: 0.7684
# Epoch 144/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4674 - binary_accuracy: 0.7809 - val_loss: 0.5405 - val_binary_accuracy: 0.7579
# Epoch 145/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4673 - binary_accuracy: 0.7786 - val_loss: 0.5367 - val_binary_accuracy: 0.7684
# Epoch 146/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4680 - binary_accuracy: 0.7786 - val_loss: 0.5344 - val_binary_accuracy: 0.7895
# Epoch 147/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7797 - val_loss: 0.5413 - val_binary_accuracy: 0.7684
# Epoch 148/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4666 - binary_accuracy: 0.7786 - val_loss: 0.5388 - val_binary_accuracy: 0.7789
# Epoch 149/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4666 - binary_accuracy: 0.7833 - val_loss: 0.5387 - val_binary_accuracy: 0.7684
# Epoch 150/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7786 - val_loss: 0.5332 - val_binary_accuracy: 0.7789
# Epoch 151/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4679 - binary_accuracy: 0.7774 - val_loss: 0.5372 - val_binary_accuracy: 0.7474
# Epoch 152/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4672 - binary_accuracy: 0.7774 - val_loss: 0.5373 - val_binary_accuracy: 0.7684
# Epoch 153/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4671 - binary_accuracy: 0.7786 - val_loss: 0.5389 - val_binary_accuracy: 0.7684
# Epoch 154/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7727 - val_loss: 0.5340 - val_binary_accuracy: 0.7895
# Epoch 155/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4672 - binary_accuracy: 0.7786 - val_loss: 0.5409 - val_binary_accuracy: 0.7684
# Epoch 156/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7750 - val_loss: 0.5375 - val_binary_accuracy: 0.7684
# Epoch 157/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4685 - binary_accuracy: 0.7739 - val_loss: 0.5383 - val_binary_accuracy: 0.7684
# Epoch 158/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7797 - val_loss: 0.5332 - val_binary_accuracy: 0.7895
# Epoch 159/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4691 - binary_accuracy: 0.7739 - val_loss: 0.5367 - val_binary_accuracy: 0.7579
# Epoch 160/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4686 - binary_accuracy: 0.7774 - val_loss: 0.5301 - val_binary_accuracy: 0.7895
# Epoch 161/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7809 - val_loss: 0.5353 - val_binary_accuracy: 0.7789
# Epoch 162/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4674 - binary_accuracy: 0.7845 - val_loss: 0.5341 - val_binary_accuracy: 0.7789
# Epoch 163/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7797 - val_loss: 0.5311 - val_binary_accuracy: 0.7684
# Epoch 164/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4658 - binary_accuracy: 0.7868 - val_loss: 0.5319 - val_binary_accuracy: 0.7579
# Epoch 165/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7821 - val_loss: 0.5336 - val_binary_accuracy: 0.7684
# Epoch 166/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4663 - binary_accuracy: 0.7809 - val_loss: 0.5353 - val_binary_accuracy: 0.7684
# Epoch 167/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4670 - binary_accuracy: 0.7739 - val_loss: 0.5294 - val_binary_accuracy: 0.7789
# Epoch 168/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4676 - binary_accuracy: 0.7797 - val_loss: 0.5361 - val_binary_accuracy: 0.7579
# Epoch 169/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5316 - val_binary_accuracy: 0.7789
# Epoch 170/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7797 - val_loss: 0.5317 - val_binary_accuracy: 0.7789
# Epoch 171/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4656 - binary_accuracy: 0.7833 - val_loss: 0.5326 - val_binary_accuracy: 0.7684
# Epoch 172/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7821 - val_loss: 0.5349 - val_binary_accuracy: 0.7684
# Epoch 173/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4655 - binary_accuracy: 0.7797 - val_loss: 0.5328 - val_binary_accuracy: 0.7789
# Epoch 174/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4665 - binary_accuracy: 0.7809 - val_loss: 0.5314 - val_binary_accuracy: 0.7789
# Epoch 175/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4667 - binary_accuracy: 0.7833 - val_loss: 0.5337 - val_binary_accuracy: 0.7579
# Epoch 176/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7821 - val_loss: 0.5353 - val_binary_accuracy: 0.7684
# Epoch 177/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7797 - val_loss: 0.5311 - val_binary_accuracy: 0.7684
# Epoch 178/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4665 - binary_accuracy: 0.7797 - val_loss: 0.5296 - val_binary_accuracy: 0.7789
# Epoch 179/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4659 - binary_accuracy: 0.7774 - val_loss: 0.5272 - val_binary_accuracy: 0.7789
# Epoch 180/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7809 - val_loss: 0.5328 - val_binary_accuracy: 0.7684
# Epoch 181/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7845 - val_loss: 0.5302 - val_binary_accuracy: 0.7789
# Epoch 182/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4663 - binary_accuracy: 0.7856 - val_loss: 0.5233 - val_binary_accuracy: 0.7789
# Epoch 183/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4655 - binary_accuracy: 0.7833 - val_loss: 0.5252 - val_binary_accuracy: 0.7789
# Epoch 184/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4667 - binary_accuracy: 0.7750 - val_loss: 0.5309 - val_binary_accuracy: 0.7789
# Epoch 185/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7715 - val_loss: 0.5331 - val_binary_accuracy: 0.7684
# Epoch 186/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4665 - binary_accuracy: 0.7809 - val_loss: 0.5279 - val_binary_accuracy: 0.7789
# Epoch 187/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4661 - binary_accuracy: 0.7774 - val_loss: 0.5314 - val_binary_accuracy: 0.7789
# Epoch 188/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7774 - val_loss: 0.5282 - val_binary_accuracy: 0.7789
# Epoch 189/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4664 - binary_accuracy: 0.7833 - val_loss: 0.5274 - val_binary_accuracy: 0.7684
# Epoch 190/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7845 - val_loss: 0.5265 - val_binary_accuracy: 0.7789
# Epoch 191/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4670 - binary_accuracy: 0.7809 - val_loss: 0.5324 - val_binary_accuracy: 0.7579
# Epoch 192/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7774 - val_loss: 0.5237 - val_binary_accuracy: 0.7895
# Epoch 193/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4655 - binary_accuracy: 0.7762 - val_loss: 0.5301 - val_binary_accuracy: 0.7579
# Epoch 194/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5285 - val_binary_accuracy: 0.7789
# Epoch 195/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7774 - val_loss: 0.5250 - val_binary_accuracy: 0.7684
# Epoch 196/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4664 - binary_accuracy: 0.7786 - val_loss: 0.5299 - val_binary_accuracy: 0.7684
# Epoch 197/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4660 - binary_accuracy: 0.7762 - val_loss: 0.5242 - val_binary_accuracy: 0.7895
# Epoch 198/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5281 - val_binary_accuracy: 0.7684
# Epoch 199/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4656 - binary_accuracy: 0.7821 - val_loss: 0.5289 - val_binary_accuracy: 0.7684
# Epoch 200/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7774 - val_loss: 0.5218 - val_binary_accuracy: 0.7789

# %%
from tensorflow.keras import initializers

#Experimenting with decaying learning rate
def build_model(num_features):
    """Return a simple linear regression model using the Keras Sequential API."""
  # Clear session and set a random seed for consistent behavior.
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)

  # Use Keras Sequential API to build a logistic regression model.
    model = tf.keras.Sequential()
    
    # create input layer
    model.add(tf.keras.Input(shape=(num_features,),
         name='Input'
    ))
    
    # create output layer
    model.add(tf.keras.layers.Dense(
        units=1,                    # there is a single output
        use_bias=True,               # include a learned bias parameter
        activation = 'sigmoid',          # Logistic regression
        kernel_initializer=initializers.RandomNormal(stddev=0.01),
        bias_initializer=initializers.RandomNormal(stddev=0.01),
        name="Output"
      ))

    initial_learning_rate = 0.005 ## 0.1
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=10000, #orginally 100000
        decay_rate=0.99, #originally 0.96
        staircase=True)
    
  # Use cross entropy as our loss and the Adam optimizer.
    model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule), 
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    )
    
    return model

# Build a model

model = build_model(num_features=X_train_scaled.shape[1])

history = model.fit(
  x = X_train_scaled,
  y = y_train,
  epochs=100,
  batch_size=50,
  validation_split=0.1,
  verbose=1
)

# grab history
history = history.history

# plot loss for train and validation
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=2, color='darkgoldenrod')
plt.plot(history['val_binary_accuracy'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Accuracy');
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6553 - binary_accuracy: 0.6243 - val_loss: 0.6127 - val_binary_accuracy: 0.7158
# Epoch 2/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5897 - binary_accuracy: 0.7208 - val_loss: 0.5959 - val_binary_accuracy: 0.7053
# Epoch 3/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5584 - binary_accuracy: 0.7362 - val_loss: 0.5874 - val_binary_accuracy: 0.7263
# Epoch 4/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5373 - binary_accuracy: 0.7562 - val_loss: 0.5776 - val_binary_accuracy: 0.7474
# Epoch 5/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5236 - binary_accuracy: 0.7562 - val_loss: 0.5817 - val_binary_accuracy: 0.7158
# Epoch 6/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5147 - binary_accuracy: 0.7644 - val_loss: 0.5733 - val_binary_accuracy: 0.7368
# Epoch 7/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5087 - binary_accuracy: 0.7668 - val_loss: 0.5746 - val_binary_accuracy: 0.7053
# Epoch 8/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5023 - binary_accuracy: 0.7680 - val_loss: 0.5748 - val_binary_accuracy: 0.7263
# Epoch 9/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4986 - binary_accuracy: 0.7656 - val_loss: 0.5761 - val_binary_accuracy: 0.7474
# Epoch 10/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4964 - binary_accuracy: 0.7680 - val_loss: 0.5750 - val_binary_accuracy: 0.7368
# Epoch 11/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4919 - binary_accuracy: 0.7691 - val_loss: 0.5755 - val_binary_accuracy: 0.7474
# Epoch 12/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4897 - binary_accuracy: 0.7750 - val_loss: 0.5757 - val_binary_accuracy: 0.7263
# Epoch 13/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4877 - binary_accuracy: 0.7727 - val_loss: 0.5730 - val_binary_accuracy: 0.7368
# Epoch 14/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4858 - binary_accuracy: 0.7797 - val_loss: 0.5732 - val_binary_accuracy: 0.7368
# Epoch 15/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4851 - binary_accuracy: 0.7762 - val_loss: 0.5734 - val_binary_accuracy: 0.7474
# Epoch 16/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4826 - binary_accuracy: 0.7774 - val_loss: 0.5747 - val_binary_accuracy: 0.7368
# Epoch 17/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4825 - binary_accuracy: 0.7762 - val_loss: 0.5728 - val_binary_accuracy: 0.7368
# Epoch 18/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4817 - binary_accuracy: 0.7750 - val_loss: 0.5698 - val_binary_accuracy: 0.7368
# Epoch 19/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4809 - binary_accuracy: 0.7821 - val_loss: 0.5767 - val_binary_accuracy: 0.7368
# Epoch 20/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4800 - binary_accuracy: 0.7762 - val_loss: 0.5791 - val_binary_accuracy: 0.7368
# Epoch 21/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4785 - binary_accuracy: 0.7762 - val_loss: 0.5722 - val_binary_accuracy: 0.7368
# Epoch 22/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4780 - binary_accuracy: 0.7786 - val_loss: 0.5743 - val_binary_accuracy: 0.7368
# Epoch 23/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4777 - binary_accuracy: 0.7786 - val_loss: 0.5721 - val_binary_accuracy: 0.7368
# Epoch 24/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4778 - binary_accuracy: 0.7786 - val_loss: 0.5743 - val_binary_accuracy: 0.7368
# Epoch 25/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4768 - binary_accuracy: 0.7797 - val_loss: 0.5768 - val_binary_accuracy: 0.7368
# Epoch 26/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4756 - binary_accuracy: 0.7809 - val_loss: 0.5720 - val_binary_accuracy: 0.7474
# Epoch 27/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4766 - binary_accuracy: 0.7750 - val_loss: 0.5783 - val_binary_accuracy: 0.7474
# Epoch 28/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4763 - binary_accuracy: 0.7750 - val_loss: 0.5742 - val_binary_accuracy: 0.7474
# Epoch 29/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4754 - binary_accuracy: 0.7821 - val_loss: 0.5751 - val_binary_accuracy: 0.7474
# Epoch 30/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4749 - binary_accuracy: 0.7762 - val_loss: 0.5769 - val_binary_accuracy: 0.7474
# Epoch 31/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4757 - binary_accuracy: 0.7797 - val_loss: 0.5779 - val_binary_accuracy: 0.7474
# Epoch 32/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4745 - binary_accuracy: 0.7786 - val_loss: 0.5721 - val_binary_accuracy: 0.7474
# Epoch 33/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4742 - binary_accuracy: 0.7786 - val_loss: 0.5756 - val_binary_accuracy: 0.7474
# Epoch 34/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4735 - binary_accuracy: 0.7786 - val_loss: 0.5740 - val_binary_accuracy: 0.7474
# Epoch 35/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4744 - binary_accuracy: 0.7797 - val_loss: 0.5729 - val_binary_accuracy: 0.7579
# Epoch 36/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4740 - binary_accuracy: 0.7774 - val_loss: 0.5773 - val_binary_accuracy: 0.7579
# Epoch 37/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4734 - binary_accuracy: 0.7797 - val_loss: 0.5763 - val_binary_accuracy: 0.7579
# Epoch 38/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4732 - binary_accuracy: 0.7797 - val_loss: 0.5731 - val_binary_accuracy: 0.7474
# Epoch 39/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4740 - binary_accuracy: 0.7797 - val_loss: 0.5781 - val_binary_accuracy: 0.7579
# Epoch 40/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4728 - binary_accuracy: 0.7786 - val_loss: 0.5716 - val_binary_accuracy: 0.7684
# Epoch 41/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4724 - binary_accuracy: 0.7797 - val_loss: 0.5763 - val_binary_accuracy: 0.7474
# Epoch 42/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4738 - binary_accuracy: 0.7739 - val_loss: 0.5727 - val_binary_accuracy: 0.7368
# Epoch 43/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4722 - binary_accuracy: 0.7774 - val_loss: 0.5736 - val_binary_accuracy: 0.7474
# Epoch 44/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4729 - binary_accuracy: 0.7727 - val_loss: 0.5756 - val_binary_accuracy: 0.7474
# Epoch 45/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4726 - binary_accuracy: 0.7762 - val_loss: 0.5705 - val_binary_accuracy: 0.7684
# Epoch 46/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4726 - binary_accuracy: 0.7762 - val_loss: 0.5702 - val_binary_accuracy: 0.7474
# Epoch 47/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4730 - binary_accuracy: 0.7797 - val_loss: 0.5738 - val_binary_accuracy: 0.7474
# Epoch 48/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4725 - binary_accuracy: 0.7809 - val_loss: 0.5715 - val_binary_accuracy: 0.7684
# Epoch 49/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7833 - val_loss: 0.5692 - val_binary_accuracy: 0.7684
# Epoch 50/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4716 - binary_accuracy: 0.7762 - val_loss: 0.5710 - val_binary_accuracy: 0.7579
# Epoch 51/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4720 - binary_accuracy: 0.7750 - val_loss: 0.5761 - val_binary_accuracy: 0.7579
# Epoch 52/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4728 - binary_accuracy: 0.7774 - val_loss: 0.5730 - val_binary_accuracy: 0.7474
# Epoch 53/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4720 - binary_accuracy: 0.7845 - val_loss: 0.5727 - val_binary_accuracy: 0.7474
# Epoch 54/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7797 - val_loss: 0.5709 - val_binary_accuracy: 0.7579
# Epoch 55/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7797 - val_loss: 0.5674 - val_binary_accuracy: 0.7474
# Epoch 56/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4721 - binary_accuracy: 0.7809 - val_loss: 0.5666 - val_binary_accuracy: 0.7684
# Epoch 57/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4719 - binary_accuracy: 0.7868 - val_loss: 0.5688 - val_binary_accuracy: 0.7579
# Epoch 58/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7762 - val_loss: 0.5747 - val_binary_accuracy: 0.7579
# Epoch 59/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7797 - val_loss: 0.5698 - val_binary_accuracy: 0.7579
# Epoch 60/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4707 - binary_accuracy: 0.7821 - val_loss: 0.5667 - val_binary_accuracy: 0.7789
# Epoch 61/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4709 - binary_accuracy: 0.7750 - val_loss: 0.5725 - val_binary_accuracy: 0.7474
# Epoch 62/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4717 - binary_accuracy: 0.7739 - val_loss: 0.5701 - val_binary_accuracy: 0.7579
# Epoch 63/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4712 - binary_accuracy: 0.7774 - val_loss: 0.5639 - val_binary_accuracy: 0.7789
# Epoch 64/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7786 - val_loss: 0.5665 - val_binary_accuracy: 0.7789
# Epoch 65/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4702 - binary_accuracy: 0.7774 - val_loss: 0.5645 - val_binary_accuracy: 0.7579
# Epoch 66/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7762 - val_loss: 0.5663 - val_binary_accuracy: 0.7684
# Epoch 67/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4702 - binary_accuracy: 0.7786 - val_loss: 0.5675 - val_binary_accuracy: 0.7684
# Epoch 68/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4704 - binary_accuracy: 0.7786 - val_loss: 0.5667 - val_binary_accuracy: 0.7474
# Epoch 69/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4705 - binary_accuracy: 0.7762 - val_loss: 0.5656 - val_binary_accuracy: 0.7684
# Epoch 70/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4699 - binary_accuracy: 0.7762 - val_loss: 0.5619 - val_binary_accuracy: 0.7684
# Epoch 71/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4694 - binary_accuracy: 0.7797 - val_loss: 0.5629 - val_binary_accuracy: 0.7789
# Epoch 72/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4715 - binary_accuracy: 0.7774 - val_loss: 0.5619 - val_binary_accuracy: 0.7789
# Epoch 73/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4704 - binary_accuracy: 0.7774 - val_loss: 0.5626 - val_binary_accuracy: 0.7789
# Epoch 74/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4706 - binary_accuracy: 0.7750 - val_loss: 0.5605 - val_binary_accuracy: 0.7684
# Epoch 75/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4701 - binary_accuracy: 0.7762 - val_loss: 0.5674 - val_binary_accuracy: 0.7474
# Epoch 76/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7727 - val_loss: 0.5620 - val_binary_accuracy: 0.7895
# Epoch 77/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4709 - binary_accuracy: 0.7833 - val_loss: 0.5673 - val_binary_accuracy: 0.7579
# Epoch 78/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4700 - binary_accuracy: 0.7786 - val_loss: 0.5649 - val_binary_accuracy: 0.7579
# Epoch 79/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7797 - val_loss: 0.5612 - val_binary_accuracy: 0.7789
# Epoch 80/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4704 - binary_accuracy: 0.7762 - val_loss: 0.5604 - val_binary_accuracy: 0.7579
# Epoch 81/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4699 - binary_accuracy: 0.7786 - val_loss: 0.5647 - val_binary_accuracy: 0.7474
# Epoch 82/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7750 - val_loss: 0.5613 - val_binary_accuracy: 0.7579
# Epoch 83/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7797 - val_loss: 0.5664 - val_binary_accuracy: 0.7579
# Epoch 84/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7774 - val_loss: 0.5598 - val_binary_accuracy: 0.7474
# Epoch 85/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4690 - binary_accuracy: 0.7821 - val_loss: 0.5584 - val_binary_accuracy: 0.7579
# Epoch 86/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4700 - binary_accuracy: 0.7821 - val_loss: 0.5566 - val_binary_accuracy: 0.7789
# Epoch 87/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4701 - binary_accuracy: 0.7750 - val_loss: 0.5605 - val_binary_accuracy: 0.7579
# Epoch 88/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7750 - val_loss: 0.5640 - val_binary_accuracy: 0.7474
# Epoch 89/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4695 - binary_accuracy: 0.7774 - val_loss: 0.5573 - val_binary_accuracy: 0.7789
# Epoch 90/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7809 - val_loss: 0.5605 - val_binary_accuracy: 0.7579
# Epoch 91/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4695 - binary_accuracy: 0.7809 - val_loss: 0.5576 - val_binary_accuracy: 0.7684
# Epoch 92/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7750 - val_loss: 0.5574 - val_binary_accuracy: 0.7789
# Epoch 93/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4698 - binary_accuracy: 0.7739 - val_loss: 0.5637 - val_binary_accuracy: 0.7368
# Epoch 94/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7797 - val_loss: 0.5513 - val_binary_accuracy: 0.7895
# Epoch 95/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4690 - binary_accuracy: 0.7797 - val_loss: 0.5568 - val_binary_accuracy: 0.7579
# Epoch 96/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7821 - val_loss: 0.5541 - val_binary_accuracy: 0.7579
# Epoch 97/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7750 - val_loss: 0.5537 - val_binary_accuracy: 0.7895
# Epoch 98/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7774 - val_loss: 0.5549 - val_binary_accuracy: 0.7579
# Epoch 99/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4692 - binary_accuracy: 0.7845 - val_loss: 0.5516 - val_binary_accuracy: 0.7684
# Epoch 100/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7821 - val_loss: 0.5551 - val_binary_accuracy: 0.7789

# %%
from tensorflow.keras import initializers

#Experimenting with Adam optimizer
def build_model(num_features):
    """Return a simple linear regression model using the Keras Sequential API."""
  # Clear session and set a random seed for consistent behavior.
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)

  # Use Keras Sequential API to build a linear regression model.
    model = tf.keras.Sequential()
    
    # create input layer
    model.add(tf.keras.Input(shape=(num_features,),
         name='Input'
    ))
    
    # create output layer
    model.add(tf.keras.layers.Dense(
        units=1,                    # there is a single output
        use_bias=True,               # include a learned bias parameter
        activation = 'sigmoid',          # Logistic regression
        kernel_initializer=initializers.RandomNormal(stddev=0.01),
        bias_initializer=initializers.RandomNormal(stddev=0.01),
        name="Output"
      ))

  # Use cross entropy as our loss and the Adam optimizer.
    model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.005), 
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    )
    
    return model

# Build a model
model = build_model(num_features=X_train_scaled.shape[1])

history = model.fit(
  x = X_train_scaled,
  y = y_train,
  epochs=200,
  batch_size=50,
  validation_split=0.1,
  verbose=1
)

# grab history
history = history.history

# plot loss for train and validation
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=2, color='darkgoldenrod')
plt.plot(history['val_loss'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Loss');

# plot accuracy for train and validation
ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=2, color='darkgoldenrod')
plt.plot(history['val_binary_accuracy'], lw=2, color='indianred')
plt.legend(['Train', 'Validation'], fontsize=10)
ax.set_xlabel('Epochs', size=10)
ax.set_title('Accuracy');
# Out:
# Epoch 1/200
# 17/17 [==============================] - 1s 32ms/step - loss: 0.6560 - binary_accuracy: 0.6113 - val_loss: 0.6180 - val_binary_accuracy: 0.6737
# Epoch 2/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5897 - binary_accuracy: 0.7232 - val_loss: 0.5996 - val_binary_accuracy: 0.7263
# Epoch 3/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5582 - binary_accuracy: 0.7362 - val_loss: 0.5894 - val_binary_accuracy: 0.7053
# Epoch 4/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5371 - binary_accuracy: 0.7515 - val_loss: 0.5792 - val_binary_accuracy: 0.7263
# Epoch 5/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5234 - binary_accuracy: 0.7550 - val_loss: 0.5829 - val_binary_accuracy: 0.7158
# Epoch 6/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5146 - binary_accuracy: 0.7597 - val_loss: 0.5742 - val_binary_accuracy: 0.7368
# Epoch 7/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5086 - binary_accuracy: 0.7633 - val_loss: 0.5752 - val_binary_accuracy: 0.7053
# Epoch 8/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5023 - binary_accuracy: 0.7691 - val_loss: 0.5756 - val_binary_accuracy: 0.7263
# Epoch 9/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4985 - binary_accuracy: 0.7680 - val_loss: 0.5767 - val_binary_accuracy: 0.7474
# Epoch 10/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4964 - binary_accuracy: 0.7644 - val_loss: 0.5756 - val_binary_accuracy: 0.7368
# Epoch 11/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4919 - binary_accuracy: 0.7668 - val_loss: 0.5759 - val_binary_accuracy: 0.7579
# Epoch 12/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4897 - binary_accuracy: 0.7727 - val_loss: 0.5761 - val_binary_accuracy: 0.7263
# Epoch 13/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4877 - binary_accuracy: 0.7750 - val_loss: 0.5734 - val_binary_accuracy: 0.7474
# Epoch 14/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4859 - binary_accuracy: 0.7774 - val_loss: 0.5736 - val_binary_accuracy: 0.7263
# Epoch 15/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4852 - binary_accuracy: 0.7750 - val_loss: 0.5737 - val_binary_accuracy: 0.7368
# Epoch 16/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4827 - binary_accuracy: 0.7774 - val_loss: 0.5751 - val_binary_accuracy: 0.7368
# Epoch 17/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4826 - binary_accuracy: 0.7762 - val_loss: 0.5732 - val_binary_accuracy: 0.7368
# Epoch 18/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4818 - binary_accuracy: 0.7739 - val_loss: 0.5702 - val_binary_accuracy: 0.7368
# Epoch 19/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4810 - binary_accuracy: 0.7845 - val_loss: 0.5770 - val_binary_accuracy: 0.7474
# Epoch 20/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4800 - binary_accuracy: 0.7762 - val_loss: 0.5794 - val_binary_accuracy: 0.7368
# Epoch 21/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4786 - binary_accuracy: 0.7774 - val_loss: 0.5724 - val_binary_accuracy: 0.7368
# Epoch 22/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4780 - binary_accuracy: 0.7774 - val_loss: 0.5746 - val_binary_accuracy: 0.7368
# Epoch 23/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4777 - binary_accuracy: 0.7809 - val_loss: 0.5724 - val_binary_accuracy: 0.7368
# Epoch 24/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4779 - binary_accuracy: 0.7750 - val_loss: 0.5745 - val_binary_accuracy: 0.7368
# Epoch 25/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4769 - binary_accuracy: 0.7809 - val_loss: 0.5771 - val_binary_accuracy: 0.7368
# Epoch 26/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4757 - binary_accuracy: 0.7797 - val_loss: 0.5723 - val_binary_accuracy: 0.7474
# Epoch 27/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4767 - binary_accuracy: 0.7762 - val_loss: 0.5786 - val_binary_accuracy: 0.7474
# Epoch 28/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4763 - binary_accuracy: 0.7750 - val_loss: 0.5744 - val_binary_accuracy: 0.7474
# Epoch 29/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4754 - binary_accuracy: 0.7833 - val_loss: 0.5752 - val_binary_accuracy: 0.7474
# Epoch 30/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4750 - binary_accuracy: 0.7774 - val_loss: 0.5772 - val_binary_accuracy: 0.7474
# Epoch 31/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4758 - binary_accuracy: 0.7821 - val_loss: 0.5781 - val_binary_accuracy: 0.7474
# Epoch 32/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4746 - binary_accuracy: 0.7797 - val_loss: 0.5723 - val_binary_accuracy: 0.7579
# Epoch 33/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4742 - binary_accuracy: 0.7786 - val_loss: 0.5758 - val_binary_accuracy: 0.7474
# Epoch 34/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4736 - binary_accuracy: 0.7797 - val_loss: 0.5743 - val_binary_accuracy: 0.7474
# Epoch 35/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4744 - binary_accuracy: 0.7786 - val_loss: 0.5731 - val_binary_accuracy: 0.7579
# Epoch 36/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4740 - binary_accuracy: 0.7774 - val_loss: 0.5775 - val_binary_accuracy: 0.7579
# Epoch 37/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4734 - binary_accuracy: 0.7797 - val_loss: 0.5765 - val_binary_accuracy: 0.7579
# Epoch 38/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4733 - binary_accuracy: 0.7797 - val_loss: 0.5733 - val_binary_accuracy: 0.7474
# Epoch 39/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4740 - binary_accuracy: 0.7821 - val_loss: 0.5783 - val_binary_accuracy: 0.7474
# Epoch 40/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4728 - binary_accuracy: 0.7786 - val_loss: 0.5718 - val_binary_accuracy: 0.7684
# Epoch 41/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4725 - binary_accuracy: 0.7797 - val_loss: 0.5765 - val_binary_accuracy: 0.7474
# Epoch 42/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4738 - binary_accuracy: 0.7750 - val_loss: 0.5729 - val_binary_accuracy: 0.7368
# Epoch 43/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4723 - binary_accuracy: 0.7762 - val_loss: 0.5738 - val_binary_accuracy: 0.7474
# Epoch 44/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4729 - binary_accuracy: 0.7727 - val_loss: 0.5758 - val_binary_accuracy: 0.7474
# Epoch 45/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4726 - binary_accuracy: 0.7750 - val_loss: 0.5707 - val_binary_accuracy: 0.7684
# Epoch 46/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4727 - binary_accuracy: 0.7774 - val_loss: 0.5704 - val_binary_accuracy: 0.7474
# Epoch 47/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4730 - binary_accuracy: 0.7797 - val_loss: 0.5740 - val_binary_accuracy: 0.7474
# Epoch 48/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4725 - binary_accuracy: 0.7809 - val_loss: 0.5717 - val_binary_accuracy: 0.7684
# Epoch 49/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7833 - val_loss: 0.5693 - val_binary_accuracy: 0.7579
# Epoch 50/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4717 - binary_accuracy: 0.7762 - val_loss: 0.5711 - val_binary_accuracy: 0.7579
# Epoch 51/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4721 - binary_accuracy: 0.7739 - val_loss: 0.5763 - val_binary_accuracy: 0.7579
# Epoch 52/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4728 - binary_accuracy: 0.7797 - val_loss: 0.5731 - val_binary_accuracy: 0.7474
# Epoch 53/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4720 - binary_accuracy: 0.7856 - val_loss: 0.5729 - val_binary_accuracy: 0.7474
# Epoch 54/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7809 - val_loss: 0.5710 - val_binary_accuracy: 0.7579
# Epoch 55/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7786 - val_loss: 0.5676 - val_binary_accuracy: 0.7474
# Epoch 56/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4721 - binary_accuracy: 0.7809 - val_loss: 0.5668 - val_binary_accuracy: 0.7684
# Epoch 57/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4720 - binary_accuracy: 0.7868 - val_loss: 0.5689 - val_binary_accuracy: 0.7579
# Epoch 58/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7762 - val_loss: 0.5748 - val_binary_accuracy: 0.7579
# Epoch 59/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7809 - val_loss: 0.5700 - val_binary_accuracy: 0.7579
# Epoch 60/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4707 - binary_accuracy: 0.7821 - val_loss: 0.5668 - val_binary_accuracy: 0.7789
# Epoch 61/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4709 - binary_accuracy: 0.7739 - val_loss: 0.5726 - val_binary_accuracy: 0.7474
# Epoch 62/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4717 - binary_accuracy: 0.7739 - val_loss: 0.5702 - val_binary_accuracy: 0.7579
# Epoch 63/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4713 - binary_accuracy: 0.7774 - val_loss: 0.5641 - val_binary_accuracy: 0.7789
# Epoch 64/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4711 - binary_accuracy: 0.7786 - val_loss: 0.5666 - val_binary_accuracy: 0.7789
# Epoch 65/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4702 - binary_accuracy: 0.7774 - val_loss: 0.5646 - val_binary_accuracy: 0.7579
# Epoch 66/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7762 - val_loss: 0.5664 - val_binary_accuracy: 0.7684
# Epoch 67/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4702 - binary_accuracy: 0.7786 - val_loss: 0.5676 - val_binary_accuracy: 0.7684
# Epoch 68/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4705 - binary_accuracy: 0.7786 - val_loss: 0.5668 - val_binary_accuracy: 0.7474
# Epoch 69/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4706 - binary_accuracy: 0.7762 - val_loss: 0.5657 - val_binary_accuracy: 0.7684
# Epoch 70/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4700 - binary_accuracy: 0.7762 - val_loss: 0.5620 - val_binary_accuracy: 0.7684
# Epoch 71/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4694 - binary_accuracy: 0.7797 - val_loss: 0.5630 - val_binary_accuracy: 0.7789
# Epoch 72/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4715 - binary_accuracy: 0.7774 - val_loss: 0.5619 - val_binary_accuracy: 0.7789
# Epoch 73/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4704 - binary_accuracy: 0.7786 - val_loss: 0.5627 - val_binary_accuracy: 0.7789
# Epoch 74/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4707 - binary_accuracy: 0.7750 - val_loss: 0.5606 - val_binary_accuracy: 0.7684
# Epoch 75/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4702 - binary_accuracy: 0.7750 - val_loss: 0.5675 - val_binary_accuracy: 0.7474
# Epoch 76/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4710 - binary_accuracy: 0.7750 - val_loss: 0.5620 - val_binary_accuracy: 0.7895
# Epoch 77/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4709 - binary_accuracy: 0.7821 - val_loss: 0.5673 - val_binary_accuracy: 0.7579
# Epoch 78/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4701 - binary_accuracy: 0.7797 - val_loss: 0.5649 - val_binary_accuracy: 0.7579
# Epoch 79/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4708 - binary_accuracy: 0.7797 - val_loss: 0.5612 - val_binary_accuracy: 0.7789
# Epoch 80/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4704 - binary_accuracy: 0.7762 - val_loss: 0.5604 - val_binary_accuracy: 0.7579
# Epoch 81/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4699 - binary_accuracy: 0.7786 - val_loss: 0.5648 - val_binary_accuracy: 0.7474
# Epoch 82/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7750 - val_loss: 0.5613 - val_binary_accuracy: 0.7579
# Epoch 83/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7797 - val_loss: 0.5664 - val_binary_accuracy: 0.7579
# Epoch 84/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7786 - val_loss: 0.5598 - val_binary_accuracy: 0.7474
# Epoch 85/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4690 - binary_accuracy: 0.7833 - val_loss: 0.5584 - val_binary_accuracy: 0.7579
# Epoch 86/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4700 - binary_accuracy: 0.7821 - val_loss: 0.5566 - val_binary_accuracy: 0.7789
# Epoch 87/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4701 - binary_accuracy: 0.7750 - val_loss: 0.5606 - val_binary_accuracy: 0.7579
# Epoch 88/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7739 - val_loss: 0.5640 - val_binary_accuracy: 0.7474
# Epoch 89/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7774 - val_loss: 0.5573 - val_binary_accuracy: 0.7789
# Epoch 90/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7809 - val_loss: 0.5605 - val_binary_accuracy: 0.7579
# Epoch 91/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4695 - binary_accuracy: 0.7809 - val_loss: 0.5576 - val_binary_accuracy: 0.7684
# Epoch 92/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7750 - val_loss: 0.5574 - val_binary_accuracy: 0.7789
# Epoch 93/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4698 - binary_accuracy: 0.7739 - val_loss: 0.5637 - val_binary_accuracy: 0.7368
# Epoch 94/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7809 - val_loss: 0.5513 - val_binary_accuracy: 0.7895
# Epoch 95/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4690 - binary_accuracy: 0.7786 - val_loss: 0.5568 - val_binary_accuracy: 0.7579
# Epoch 96/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7809 - val_loss: 0.5541 - val_binary_accuracy: 0.7579
# Epoch 97/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7750 - val_loss: 0.5537 - val_binary_accuracy: 0.7895
# Epoch 98/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7774 - val_loss: 0.5549 - val_binary_accuracy: 0.7579
# Epoch 99/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4693 - binary_accuracy: 0.7845 - val_loss: 0.5516 - val_binary_accuracy: 0.7684
# Epoch 100/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7821 - val_loss: 0.5551 - val_binary_accuracy: 0.7789
# Epoch 101/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7809 - val_loss: 0.5547 - val_binary_accuracy: 0.7684
# Epoch 102/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4697 - binary_accuracy: 0.7727 - val_loss: 0.5538 - val_binary_accuracy: 0.7579
# Epoch 103/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4693 - binary_accuracy: 0.7774 - val_loss: 0.5560 - val_binary_accuracy: 0.7579
# Epoch 104/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7750 - val_loss: 0.5558 - val_binary_accuracy: 0.7684
# Epoch 105/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7762 - val_loss: 0.5542 - val_binary_accuracy: 0.7684
# Epoch 106/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4690 - binary_accuracy: 0.7786 - val_loss: 0.5523 - val_binary_accuracy: 0.7789
# Epoch 107/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4687 - binary_accuracy: 0.7786 - val_loss: 0.5494 - val_binary_accuracy: 0.7579
# Epoch 108/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7774 - val_loss: 0.5529 - val_binary_accuracy: 0.7474
# Epoch 109/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7821 - val_loss: 0.5503 - val_binary_accuracy: 0.7579
# Epoch 110/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4673 - binary_accuracy: 0.7786 - val_loss: 0.5504 - val_binary_accuracy: 0.7789
# Epoch 111/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4694 - binary_accuracy: 0.7774 - val_loss: 0.5515 - val_binary_accuracy: 0.7579
# Epoch 112/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7762 - val_loss: 0.5408 - val_binary_accuracy: 0.8000
# Epoch 113/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4698 - binary_accuracy: 0.7845 - val_loss: 0.5538 - val_binary_accuracy: 0.7684
# Epoch 114/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7809 - val_loss: 0.5470 - val_binary_accuracy: 0.7895
# Epoch 115/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4680 - binary_accuracy: 0.7762 - val_loss: 0.5516 - val_binary_accuracy: 0.7579
# Epoch 116/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4676 - binary_accuracy: 0.7762 - val_loss: 0.5496 - val_binary_accuracy: 0.7684
# Epoch 117/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4689 - binary_accuracy: 0.7797 - val_loss: 0.5470 - val_binary_accuracy: 0.7579
# Epoch 118/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4676 - binary_accuracy: 0.7774 - val_loss: 0.5478 - val_binary_accuracy: 0.7684
# Epoch 119/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4688 - binary_accuracy: 0.7797 - val_loss: 0.5470 - val_binary_accuracy: 0.7789
# Epoch 120/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4672 - binary_accuracy: 0.7833 - val_loss: 0.5490 - val_binary_accuracy: 0.7684
# Epoch 121/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4678 - binary_accuracy: 0.7845 - val_loss: 0.5444 - val_binary_accuracy: 0.7789
# Epoch 122/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4676 - binary_accuracy: 0.7809 - val_loss: 0.5469 - val_binary_accuracy: 0.7684
# Epoch 123/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4682 - binary_accuracy: 0.7809 - val_loss: 0.5469 - val_binary_accuracy: 0.7684
# Epoch 124/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4680 - binary_accuracy: 0.7774 - val_loss: 0.5449 - val_binary_accuracy: 0.7789
# Epoch 125/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4681 - binary_accuracy: 0.7786 - val_loss: 0.5476 - val_binary_accuracy: 0.7684
# Epoch 126/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4687 - binary_accuracy: 0.7821 - val_loss: 0.5484 - val_binary_accuracy: 0.7474
# Epoch 127/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4673 - binary_accuracy: 0.7821 - val_loss: 0.5467 - val_binary_accuracy: 0.7684
# Epoch 128/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4678 - binary_accuracy: 0.7750 - val_loss: 0.5495 - val_binary_accuracy: 0.7684
# Epoch 129/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4678 - binary_accuracy: 0.7797 - val_loss: 0.5416 - val_binary_accuracy: 0.7684
# Epoch 130/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4666 - binary_accuracy: 0.7845 - val_loss: 0.5418 - val_binary_accuracy: 0.7789
# Epoch 131/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4670 - binary_accuracy: 0.7786 - val_loss: 0.5406 - val_binary_accuracy: 0.7789
# Epoch 132/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4681 - binary_accuracy: 0.7750 - val_loss: 0.5447 - val_binary_accuracy: 0.7684
# Epoch 133/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7774 - val_loss: 0.5416 - val_binary_accuracy: 0.7789
# Epoch 134/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4682 - binary_accuracy: 0.7809 - val_loss: 0.5379 - val_binary_accuracy: 0.7684
# Epoch 135/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7809 - val_loss: 0.5460 - val_binary_accuracy: 0.7579
# Epoch 136/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4671 - binary_accuracy: 0.7762 - val_loss: 0.5463 - val_binary_accuracy: 0.7684
# Epoch 137/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4664 - binary_accuracy: 0.7762 - val_loss: 0.5419 - val_binary_accuracy: 0.7684
# Epoch 138/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7774 - val_loss: 0.5357 - val_binary_accuracy: 0.7895
# Epoch 139/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5398 - val_binary_accuracy: 0.7684
# Epoch 140/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4671 - binary_accuracy: 0.7809 - val_loss: 0.5447 - val_binary_accuracy: 0.7684
# Epoch 141/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4675 - binary_accuracy: 0.7750 - val_loss: 0.5439 - val_binary_accuracy: 0.7684
# Epoch 142/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4687 - binary_accuracy: 0.7762 - val_loss: 0.5383 - val_binary_accuracy: 0.7789
# Epoch 143/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7833 - val_loss: 0.5420 - val_binary_accuracy: 0.7684
# Epoch 144/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4674 - binary_accuracy: 0.7809 - val_loss: 0.5408 - val_binary_accuracy: 0.7579
# Epoch 145/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4674 - binary_accuracy: 0.7786 - val_loss: 0.5369 - val_binary_accuracy: 0.7684
# Epoch 146/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4680 - binary_accuracy: 0.7786 - val_loss: 0.5347 - val_binary_accuracy: 0.7895
# Epoch 147/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7797 - val_loss: 0.5416 - val_binary_accuracy: 0.7684
# Epoch 148/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4666 - binary_accuracy: 0.7786 - val_loss: 0.5390 - val_binary_accuracy: 0.7789
# Epoch 149/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4666 - binary_accuracy: 0.7833 - val_loss: 0.5389 - val_binary_accuracy: 0.7684
# Epoch 150/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7786 - val_loss: 0.5334 - val_binary_accuracy: 0.7789
# Epoch 151/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4679 - binary_accuracy: 0.7774 - val_loss: 0.5374 - val_binary_accuracy: 0.7474
# Epoch 152/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4673 - binary_accuracy: 0.7774 - val_loss: 0.5375 - val_binary_accuracy: 0.7684
# Epoch 153/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4671 - binary_accuracy: 0.7762 - val_loss: 0.5391 - val_binary_accuracy: 0.7684
# Epoch 154/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4696 - binary_accuracy: 0.7727 - val_loss: 0.5342 - val_binary_accuracy: 0.7895
# Epoch 155/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4672 - binary_accuracy: 0.7786 - val_loss: 0.5411 - val_binary_accuracy: 0.7684
# Epoch 156/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7750 - val_loss: 0.5376 - val_binary_accuracy: 0.7684
# Epoch 157/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4685 - binary_accuracy: 0.7739 - val_loss: 0.5385 - val_binary_accuracy: 0.7684
# Epoch 158/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5333 - val_binary_accuracy: 0.7895
# Epoch 159/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4691 - binary_accuracy: 0.7739 - val_loss: 0.5368 - val_binary_accuracy: 0.7579
# Epoch 160/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4686 - binary_accuracy: 0.7774 - val_loss: 0.5302 - val_binary_accuracy: 0.7895
# Epoch 161/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4663 - binary_accuracy: 0.7809 - val_loss: 0.5355 - val_binary_accuracy: 0.7789
# Epoch 162/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4674 - binary_accuracy: 0.7845 - val_loss: 0.5342 - val_binary_accuracy: 0.7789
# Epoch 163/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7797 - val_loss: 0.5312 - val_binary_accuracy: 0.7684
# Epoch 164/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4658 - binary_accuracy: 0.7868 - val_loss: 0.5320 - val_binary_accuracy: 0.7579
# Epoch 165/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7821 - val_loss: 0.5337 - val_binary_accuracy: 0.7684
# Epoch 166/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4663 - binary_accuracy: 0.7809 - val_loss: 0.5354 - val_binary_accuracy: 0.7684
# Epoch 167/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4670 - binary_accuracy: 0.7739 - val_loss: 0.5295 - val_binary_accuracy: 0.7789
# Epoch 168/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4676 - binary_accuracy: 0.7797 - val_loss: 0.5361 - val_binary_accuracy: 0.7579
# Epoch 169/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5317 - val_binary_accuracy: 0.7789
# Epoch 170/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7797 - val_loss: 0.5318 - val_binary_accuracy: 0.7789
# Epoch 171/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4656 - binary_accuracy: 0.7833 - val_loss: 0.5327 - val_binary_accuracy: 0.7684
# Epoch 172/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7821 - val_loss: 0.5350 - val_binary_accuracy: 0.7684
# Epoch 173/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4655 - binary_accuracy: 0.7797 - val_loss: 0.5329 - val_binary_accuracy: 0.7789
# Epoch 174/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4665 - binary_accuracy: 0.7809 - val_loss: 0.5314 - val_binary_accuracy: 0.7789
# Epoch 175/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4667 - binary_accuracy: 0.7833 - val_loss: 0.5338 - val_binary_accuracy: 0.7579
# Epoch 176/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7821 - val_loss: 0.5354 - val_binary_accuracy: 0.7684
# Epoch 177/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7797 - val_loss: 0.5312 - val_binary_accuracy: 0.7684
# Epoch 178/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4665 - binary_accuracy: 0.7797 - val_loss: 0.5297 - val_binary_accuracy: 0.7789
# Epoch 179/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4659 - binary_accuracy: 0.7774 - val_loss: 0.5273 - val_binary_accuracy: 0.7789
# Epoch 180/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - binary_accuracy: 0.7809 - val_loss: 0.5328 - val_binary_accuracy: 0.7684
# Epoch 181/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4669 - binary_accuracy: 0.7845 - val_loss: 0.5303 - val_binary_accuracy: 0.7789
# Epoch 182/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4663 - binary_accuracy: 0.7856 - val_loss: 0.5234 - val_binary_accuracy: 0.7789
# Epoch 183/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4655 - binary_accuracy: 0.7833 - val_loss: 0.5253 - val_binary_accuracy: 0.7789
# Epoch 184/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4667 - binary_accuracy: 0.7750 - val_loss: 0.5309 - val_binary_accuracy: 0.7789
# Epoch 185/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - binary_accuracy: 0.7727 - val_loss: 0.5332 - val_binary_accuracy: 0.7684
# Epoch 186/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4665 - binary_accuracy: 0.7809 - val_loss: 0.5280 - val_binary_accuracy: 0.7789
# Epoch 187/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4661 - binary_accuracy: 0.7774 - val_loss: 0.5315 - val_binary_accuracy: 0.7789
# Epoch 188/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7774 - val_loss: 0.5282 - val_binary_accuracy: 0.7789
# Epoch 189/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4664 - binary_accuracy: 0.7833 - val_loss: 0.5274 - val_binary_accuracy: 0.7684
# Epoch 190/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7845 - val_loss: 0.5266 - val_binary_accuracy: 0.7789
# Epoch 191/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4670 - binary_accuracy: 0.7809 - val_loss: 0.5324 - val_binary_accuracy: 0.7579
# Epoch 192/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7774 - val_loss: 0.5237 - val_binary_accuracy: 0.7895
# Epoch 193/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4655 - binary_accuracy: 0.7762 - val_loss: 0.5302 - val_binary_accuracy: 0.7579
# Epoch 194/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5285 - val_binary_accuracy: 0.7789
# Epoch 195/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7774 - val_loss: 0.5251 - val_binary_accuracy: 0.7684
# Epoch 196/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4664 - binary_accuracy: 0.7786 - val_loss: 0.5299 - val_binary_accuracy: 0.7684
# Epoch 197/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4660 - binary_accuracy: 0.7762 - val_loss: 0.5243 - val_binary_accuracy: 0.7895
# Epoch 198/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7786 - val_loss: 0.5282 - val_binary_accuracy: 0.7684
# Epoch 199/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4656 - binary_accuracy: 0.7821 - val_loss: 0.5289 - val_binary_accuracy: 0.7684
# Epoch 200/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4662 - binary_accuracy: 0.7774 - val_loss: 0.5218 - val_binary_accuracy: 0.7789

# %% [markdown]
# EPOCHS | BATCH | OPTIMIZER | LEARNING RATE | INITIALIZER |TRAIN ACC|VAL ACC
# -|-|-|-|-|-|-
# 20|50|SGD|0.005|Y|75.03|75.79
# 40|50|SGD|0.005|Y|75.50|76.84
# 15|10|SGD|0.005|Y|76.21|74.74
# 30|10|SGD|0.005|N|76.56|74.74
# 40|100|SGD|0.001|N|71.26|75.79
# 40|100|SGD|0.001|N|71.26|75.79
# 50|50|Adam|0.01|N|77.03|75.79
# 50|10|Adam|0.005|N|76.33|75.79
# 50|10|Adam|0.001|N|77.50|75.79
# 50|1|Adam|0.0005|N|77.15|74.74
# 100|5|Adam|0.001|N|77.98|76.84
# 30|30|Adam|0.001|Y|77.50|74.74
# 50|5|Adam|0.0001|Y|75.74|76.84
# 100|50|Adam|0.01|Y|77.39|77.89
# 200|50|Adam|0.005|Y|77.74|77.89

# %% [markdown]
# ## Model Selection: Chose model with highest val accuracy + better learning curve than the model with equivalent val accuracy.

# %%
y_train_pred_tf = model.predict(x=X_train_scaled).flatten()
y_train_pred_tf = np.where(y_train_pred_tf>=0.5, 1, 0)

conf_matrix = tf.math.confusion_matrix(
    y_train,
    y_train_pred_tf,
    num_classes=None,
    weights=None,
    dtype=tf.dtypes.int32,
    name=None
)
conf_matrix
# Out:
# 30/30 [==============================] - 0s 468us/step
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[342,  94],
#        [110, 398]], dtype=int32)>

# %%
confusion_matrix_plot(conf_matrix.numpy())

# %% [markdown]
# # Evaluating Model

# %%
y_test_pred_tf = model.predict(x=X_test_scaled).flatten()
y_test_pred_tf = np.where(y_test_pred_tf>=0.5, 1, 0)

print('Test, misclassified examples: %d' % (y_test != y_test_pred_tf).sum())
error_test_tf = (y_test != y_test_pred_tf).sum()/len(y_test_pred_tf)
print('Test, prediction accuracy: %.3f'% (1-error_test_tf))
# Out:
# 7/7 [==============================] - 0s 806us/step
# Test, misclassified examples: 59
# Test, prediction accuracy: 0.705

# %%
conf_matrix = tf.math.confusion_matrix(
    y_test,
    y_test_pred_tf,
    num_classes=None,
    weights=None,
    dtype=tf.dtypes.int32,
    name=None
)
confusion_matrix_plot(conf_matrix.numpy())

# %%
#Precision Score
p = tf.keras.metrics.Precision(
    thresholds=None, top_k=None, class_id=None, name=None, dtype=None
)
p.update_state(y_test, y_test_pred_tf)  #18/(18+3)
print("Precision score: %3f" %p.result().numpy())
# Out:
# Precision score: 0.699029

# %%
#Recall Score
r = tf.keras.metrics.Recall(
    thresholds=None, top_k=None, class_id=None, name=None, dtype=None
)
r.update_state(y_test, y_test_pred_tf) #18/(18+1)
print("Recall score: %.3f" %r.result().numpy())
# Out:
# Recall score: 0.600

# %%
#F1 Score
print("F1 score:",
    2*((p.result().numpy()*r.result().numpy())/(p.result().numpy()+r.result().numpy())))
# Out:
# F1 score: 0.6457399725914001
